# %% [markdown]
# # Crawling 크롤링 + 전처리

# %%
# 웹 사이트로부터 데이터를 얻어오는 클래스
import requests
import json

class Requester:
    def get_data(self, url, parameters = {}):
        if (url is None) or (url.strip() is ''):
            raise Exception('url should not be empty')
        
        response = requests.get(url.strip(), params = parameters)
        if response.status_code is not 200:
            print('[ERROER]Can not receive response')

        response_text = (response.text is None) and '{}' or response.text
        json_response = json.loads(response_text)
        return json_response

# %% [markdown]
# ## '집들이 목록의 고유키'을 크롤링하는 클래스

# %%
# 홈페이지 주소: https://ohou.se/projects?writer=self
from time import sleep

class HouseWarmingCrawler:
    def __init__(self):
        self.house_warming_item_ids = list()
        self.requester = Requester()
        self.default_page_size = 100 # 1페이지에 출력될 아이템 갯수
    
    def get_house_warming_data_by_page(self, page):
        parameters = {
             'v': str(2), # 고정 queryParam 값. v인걸 보아 API 버전 정보인듯?
             'writer': 'self', # 고정 queryParam 값. 뭔지 모르겠음.
             'per': str(self.default_page_size), # 고정 queryParam 값. 페이에 출력될 아이템 갯수
             'page': str(page)
        }
        url = 'https://ohou.se/projects.json'
        response = self.requester.get_data(url, parameters)
        return response
    
    def collect_house_warming_list(self, projects = []):
        for project in projects:
            self.house_warming_item_ids.append(project['id'])
        
    def collect(self):
        self.house_warming_item_ids = list()
        
        has_next_page = True
        current_page = 1
        while has_next_page is True:
            print('> Start to collect house warming list. current_page:', current_page)
            response = self.get_house_warming_data_by_page(current_page)
            if (response['projects'] is not None) and (len(response['projects']) > 0):
                self.collect_house_warming_list(response['projects'])
                print(response['next'])
                has_next_page = response['next']
                current_page = current_page + 1
                sleep(3)

# %%
house_warming_crawler = HouseWarmingCrawler()
house_warming_crawler.collect()

print('> Total main house warming item count:', len(house_warming_crawler.house_warming_item_ids))
# Out:
# > Start to collect house warming list. current_page: 1
# True
# > Start to collect house warming list. current_page: 2
# True
# > Start to collect house warming list. current_page: 3
# True
# > Start to collect house warming list. current_page: 4
# True
# > Start to collect house warming list. current_page: 5
# True
# > Start to collect house warming list. current_page: 6
# True
# > Start to collect house warming list. current_page: 7
# True
# > Start to collect house warming list. current_page: 8
# True
# > Start to collect house warming list. current_page: 9
# True
# > Start to collect house warming list. current_page: 10
# True
# > Start to collect house warming list. current_page: 11
# True
# > Start to collect house warming list. current_page: 12
# True
# > Start to collect house warming list. current_page: 13
# True
# > Start to collect house warming list. current_page: 14
# True
# > Start to collect house warming list. current_page: 15
# True
# > Start to collect house warming list. current_page: 16
# True
# > Start to collect house warming list. current_page: 17
# True
# > Start to collect house warming list. current_page: 18
# True
# > Start to collect house warming list. current_page: 19
# True
# > Start to collect house warming list. current_page: 20
# True
# > Start to collect house warming list. current_page: 21
# True
# > Start to collect house warming list. current_page: 22
# True
# > Start to collect house warming list. current_page: 23
# True
# > Start to collect house warming list. current_page: 24
# True
# > Start to collect house warming list. current_page: 25
# True
# > Start to collect house warming list. current_page: 26
# True
# > Start to collect house warming list. current_page: 27
# True
# > Start to collect house warming list. current_page: 28
# True
# > Start to collect house warming list. current_page: 29
# True
# > Start to collect house warming list. current_page: 30
# True
# > Start to collect house warming list. current_page: 31
# True
# > Start to collect house warming list. current_page: 32
# True
# > Start to collect house warming list. current_page: 33
# True
# > Start to collect house warming list. current_page: 34
# True
# > Start to collect house warming list. current_page: 35
# True
# > Start to collect house warming list. current_page: 36
# True
# > Start to collect house warming list. current_page: 37
# True
# > Start to collect house warming list. current_page: 38
# True
# > Start to collect house warming list. current_page: 39
# True
# > Start to collect house warming list. current_page: 40
# True
# > Start to collect house warming list. current_page: 41
# True
# > Start to collect house warming list. current_page: 42
# False
# > Total main house warming item count: 4155

# %% [markdown]
# ## '집들이 ' 항목의  '상품' 및 관련된 '리뷰텍스트 등'을 크롤링하는 클래스

# %%
from time import sleep

class HouseWarmingItemDetailCrawler:
    def __init__(self, item_ids = []):
        self.house_warming_details = list()
        self.item_ids = item_ids
        self.requester = Requester()
    
    def get_detail_data_by_item_id(self, item_id):
        parameters = {
             'v': str(4), # 고정 queryParam 값. v인걸 보아 API 버전 정보인듯?
        }
        url = 'https://ohou.se/projects/' + str(item_id) + '/detail.json'
        response = self.requester.get_data(url, parameters)
        return response
    
    def collect_house_warming_detail(self, project_detail = []):
        purchased_product_ids = [ product['id'] for product in project_detail['bucketplace_document_supplements']['products'] ]
        
        self.house_warming_details.append({
            'id': project_detail['id'],
            
            'residence': project_detail['residence'], # 주거 형태
            'area': project_detail['area'], # 평수
            'region': project_detail['region'],  # 주거지 지역
            'expertise': project_detail['expertise'], # 인테리어 포스트 카테고리
            
            'color_list': ','.join(project_detail['color_list']),
            'style_list': ','.join(project_detail['style_list']),
            'constructions': ','.join(project_detail['constructions']),
            
            'purchased_product_ids': purchased_product_ids, # 구매한 제품 아이디 목록
            
            'family_list': project_detail['family_list'], # 가족 구성원 정보
            'like_count': project_detail['like_count'], #  집 인테리어 포스트의 좋아요 갯수
            'reply_count': project_detail['reply_count'],  # 집 인테리어 포스트에 남겨진 답글 갯수
            'scrap_count': project_detail['scrap_count'],  # 집 인테리어 포스트를 스크랩한 총 갯수
            'view_count': project_detail['view_count'],  # 집 인테리어 포스트를 본 횟수
            'share_count': project_detail['share_count'] # 해당 집 인테리어 포스트를 공유한 횟수
        })
        
    def collect(self):
        self.house_warming_details = list()
        if (self.item_ids is None) or (len(self.item_ids) <= 0):
            return
        
        for item_id in self.item_ids:
            response = self.get_detail_data_by_item_id(item_id)
            print('Collect item detail item_id:', item_id)
            if (response['project'] is not None) and (len(response['project']) > 0):
                    self.collect_house_warming_detail(response['project'])
            print('...')

# %%
house_warming_item_detail_crawler = HouseWarmingItemDetailCrawler(item_ids = house_warming_crawler.house_warming_item_ids)
house_warming_item_detail_crawler.collect()
# Out:
# Collect item detail item_id: 40578
# ...
# Collect item detail item_id: 39868
# ...
# Collect item detail item_id: 39270
# ...
# Collect item detail item_id: 39218
# ...
# Collect item detail item_id: 38991
# ...
# Collect item detail item_id: 40580
# ...
# Collect item detail item_id: 40055
# ...
# Collect item detail item_id: 39404
# ...
# Collect item detail item_id: 39302
# ...
# Collect item detail item_id: 38844
# ...
# Collect item detail item_id: 40576
# ...
# Collect item detail item_id: 39858
# ...
# Collect item detail item_id: 39211
# ...
# Collect item detail item_id: 38993
# ...
# Collect item detail item_id: 38718
# ...
# Collect item detail item_id: 40577
# ...
# Collect item detail item_id: 39779
# ...
# Collect item detail item_id: 39714
# ...
# Collect item detail item_id: 39337
# ...
# Collect item detail item_id: 38539
# ...
# Collect item detail item_id: 40579
# ...
# Collect item detail item_id: 39744
# ...
# Collect item detail item_id: 39041
# ...
# Collect item detail item_id: 40402
# ...
# Collect item detail item_id: 39831
# ...
# Collect item detail item_id: 39147
# ...
# Collect item detail item_id: 39038
# ...
# Collect item detail item_id: 40469
# ...
# Collect item detail item_id: 39820
# ...
# Collect item detail item_id: 39380
# ...
# Collect item detail item_id: 38906
# ...
# Collect item detail item_id: 39668
# ...
# Collect item detail item_id: 39198
# ...
# Collect item detail item_id: 38939
# ...
# Collect item detail item_id: 38830
# ...
# Collect item detail item_id: 39916
# ...
# Collect item detail item_id: 39486
# ...
# Collect item detail item_id: 39269
# ...
# Collect item detail item_id: 38992
# ...
# Collect item detail item_id: 38295
# ...
# Collect item detail item_id: 39861
# ...
# Collect item detail item_id: 39540
# ...
# Collect item detail item_id: 39278
# ...
# Collect item detail item_id: 38692
# ...
# Collect item detail item_id: 38359
# ...
# Collect item detail item_id: 40089
# ...
# Collect item detail item_id: 39494
# ...
# Collect item detail item_id: 39445
# ...
# Collect item detail item_id: 39334
# ...
# Collect item detail item_id: 38694
# ...
# Collect item detail item_id: 40356
# ...
# Collect item detail item_id: 40091
# ...
# Collect item detail item_id: 39520
# ...
# Collect item detail item_id: 38862
# ...
# Collect item detail item_id: 40274
# ...
# Collect item detail item_id: 39513
# ...
# Collect item detail item_id: 38532
# ...
# Collect item detail item_id: 37801
# ...
# Collect item detail item_id: 40113
# ...
# Collect item detail item_id: 39482
# ...
# Collect item detail item_id: 38758
# ...
# Collect item detail item_id: 38752
# ...
# Collect item detail item_id: 39860
# ...
# Collect item detail item_id: 39405
# ...
# Collect item detail item_id: 38863
# ...
# Collect item detail item_id: 38600
# ...
# Collect item detail item_id: 38537
# ...
# Collect item detail item_id: 39816
# ...
# Collect item detail item_id: 39528
# ...
# Collect item detail item_id: 38751
# ...
# Collect item detail item_id: 38566
# ...
# Collect item detail item_id: 38304
# ...
# Collect item detail item_id: 39839
# ...
# Collect item detail item_id: 39324
# ...
# Collect item detail item_id: 38908
# ...
# Collect item detail item_id: 38753
# ...
# Collect item detail item_id: 38415
# ...
# Collect item detail item_id: 39700
# ...
# Collect item detail item_id: 39430
# ...
# Collect item detail item_id: 39264
# ...
# Collect item detail item_id: 38320
# ...
# Collect item detail item_id: 38277
# ...
# Collect item detail item_id: 39701
# ...
# Collect item detail item_id: 39326
# ...
# Collect item detail item_id: 38439
# ...
# Collect item detail item_id: 39699
# ...
# Collect item detail item_id: 39366
# ...
# Collect item detail item_id: 38602
# ...
# Collect item detail item_id: 38564
# ...
# Collect item detail item_id: 39702
# ...
# Collect item detail item_id: 39367
# ...
# Collect item detail item_id: 38492
# ...
# Collect item detail item_id: 38299
# ...
# Collect item detail item_id: 39697
# ...
# Collect item detail item_id: 39355
# ...
# Collect item detail item_id: 38759
# ...
# Collect item detail item_id: 38554
# ...
# Collect item detail item_id: 38317
# ...
# Collect item detail item_id: 39501
# ...
# Collect item detail item_id: 38764
# ...
# Collect item detail item_id: 38601
# ...
# Collect item detail item_id: 38292
# ...
# Collect item detail item_id: 38244
# ...
# Collect item detail item_id: 37087
# ...
# Collect item detail item_id: 39596
# ...
# Collect item detail item_id: 39290
# ...
# Collect item detail item_id: 38616
# ...
# Collect item detail item_id: 38298
# ...
# Collect item detail item_id: 38118
# ...
# Collect item detail item_id: 39461
# ...
# Collect item detail item_id: 39261
# ...
# Collect item detail item_id: 39073
# ...
# Collect item detail item_id: 38536
# ...
# Collect item detail item_id: 38388
# ...
# Collect item detail item_id: 39460
# ...
# Collect item detail item_id: 39008
# ...
# Collect item detail item_id: 38354
# ...
# Collect item detail item_id: 39490
# ...
# Collect item detail item_id: 39336
# ...
# Collect item detail item_id: 38302
# ...
# Collect item detail item_id: 36583
# ...
# Collect item detail item_id: 39202
# ...
# Collect item detail item_id: 38978
# ...
# Collect item detail item_id: 38430
# ...
# Collect item detail item_id: 38280
# ...
# Collect item detail item_id: 39456
# ...
# Collect item detail item_id: 39200
# ...
# Collect item detail item_id: 38425
# ...
# Collect item detail item_id: 38313
# ...
# Collect item detail item_id: 38261
# ...
# Collect item detail item_id: 39446
# ...
# Collect item detail item_id: 39199
# ...
# Collect item detail item_id: 38479
# ...
# Collect item detail item_id: 38140
# ...
# Collect item detail item_id: 37978
# ...
# Collect item detail item_id: 39080
# ...
# Collect item detail item_id: 39364
# ...
# Collect item detail item_id: 38385
# ...
# Collect item detail item_id: 38255
# ...
# Collect item detail item_id: 37400
# ...
# Collect item detail item_id: 39109
# ...
# Collect item detail item_id: 38475
# ...
# Collect item detail item_id: 37714
# ...
# Collect item detail item_id: 37111
# ...
# Collect item detail item_id: 38964
# ...
# Collect item detail item_id: 37820
# ...
# Collect item detail item_id: 39044
# ...
# Collect item detail item_id: 37761
# ...
# Collect item detail item_id: 37327
# ...
# Collect item detail item_id: 38775
# ...
# Collect item detail item_id: 38471
# ...
# Collect item detail item_id: 38319
# ...
# Collect item detail item_id: 38424
# ...
# Collect item detail item_id: 38414
# ...
# Collect item detail item_id: 38278
# ...
# Collect item detail item_id: 37675
# ...
# Collect item detail item_id: 38577
# ...
# Collect item detail item_id: 37819
# ...
# Collect item detail item_id: 37734
# ...
# Collect item detail item_id: 37599
# ...
# Collect item detail item_id: 38360
# ...
# Collect item detail item_id: 38293
# ...
# Collect item detail item_id: 38276
# ...
# Collect item detail item_id: 38210
# ...
# Collect item detail item_id: 38817
# ...
# Collect item detail item_id: 38301
# ...
# Collect item detail item_id: 38214
# ...
# Collect item detail item_id: 37325
# ...
# Collect item detail item_id: 38384
# ...
# Collect item detail item_id: 38232
# ...
# Collect item detail item_id: 38476
# ...
# Collect item detail item_id: 38275
# ...
# Collect item detail item_id: 38254
# ...
# Collect item detail item_id: 37740
# ...
# Collect item detail item_id: 38454
# ...
# Collect item detail item_id: 38251
# ...
# Collect item detail item_id: 37224
# ...
# Collect item detail item_id: 38300
# ...
# Collect item detail item_id: 38225
# ...
# Collect item detail item_id: 38194
# ...
# Collect item detail item_id: 37210
# ...
# Collect item detail item_id: 38395
# ...
# Collect item detail item_id: 38212
# ...
# Collect item detail item_id: 38149
# ...
# Collect item detail item_id: 38039
# ...
# Collect item detail item_id: 38412
# ...
# Collect item detail item_id: 38224
# ...
# Collect item detail item_id: 38220
# ...
# Collect item detail item_id: 38040
# ...
# Collect item detail item_id: 38267
# ...
# Collect item detail item_id: 38198
# ...
# Collect item detail item_id: 38110
# ...
# Collect item detail item_id: 37944
# ...
# Collect item detail item_id: 37442
# ...
# Collect item detail item_id: 26280
# ...
# Collect item detail item_id: 38018
# ...
# Collect item detail item_id: 37776
# ...
# Collect item detail item_id: 27688
# ...
# Collect item detail item_id: 38213
# ...
# Collect item detail item_id: 37977
# ...
# Collect item detail item_id: 37816
# ...
# Collect item detail item_id: 37342
# ...
# Collect item detail item_id: 37255
# ...
# Collect item detail item_id: 32849
# ...
# Collect item detail item_id: 37854
# ...
# Collect item detail item_id: 37963
# ...
# Collect item detail item_id: 37926
# ...
# Collect item detail item_id: 31476
# ...
# Collect item detail item_id: 38249
# ...
# Collect item detail item_id: 37764
# ...
# Collect item detail item_id: 36905
# ...
# Collect item detail item_id: 37305
# ...
# Collect item detail item_id: 37848
# ...
# Collect item detail item_id: 38116
# ...
# Collect item detail item_id: 37379
# ...
# Collect item detail item_id: 38152
# ...
# Collect item detail item_id: 37670
# ...
# Collect item detail item_id: 38191
# ...
# Collect item detail item_id: 37483
# ...
# Collect item detail item_id: 37194
# ...
# Collect item detail item_id: 38205
# ...
# Collect item detail item_id: 37693
# ...
# Collect item detail item_id: 37680
# ...
# Collect item detail item_id: 38188
# ...
# Collect item detail item_id: 37724
# ...
# Collect item detail item_id: 37536
# ...
# Collect item detail item_id: 37522
# ...
# Collect item detail item_id: 37598
# ...
# Collect item detail item_id: 37469
# ...
# Collect item detail item_id: 37399
# ...
# Collect item detail item_id: 37679
# ...
# Collect item detail item_id: 37576
# ...
# Collect item detail item_id: 36456
# ...
# Collect item detail item_id: 37676
# ...
# Collect item detail item_id: 37467
# ...
# Collect item detail item_id: 37924
# ...
# Collect item detail item_id: 37265
# ...
# Collect item detail item_id: 37713
# ...
# Collect item detail item_id: 37220
# ...
# Collect item detail item_id: 37156
# ...
# Collect item detail item_id: 37715
# ...
# Collect item detail item_id: 37384
# ...
# Collect item detail item_id: 37286
# ...
# Collect item detail item_id: 37614
# ...
# Collect item detail item_id: 37528
# ...
# Collect item detail item_id: 37242
# ...
# Collect item detail item_id: 37196
# ...
# Collect item detail item_id: 37927
# ...
# Collect item detail item_id: 37434
# ...
# Collect item detail item_id: 37260
# ...
# Collect item detail item_id: 34176
# ...
# Collect item detail item_id: 37331
# ...
# Collect item detail item_id: 37593
# ...
# Collect item detail item_id: 37438
# ...
# Collect item detail item_id: 37317
# ...
# Collect item detail item_id: 36740
# ...
# Collect item detail item_id: 37649
# ...
# Collect item detail item_id: 37524
# ...
# Collect item detail item_id: 37332
# ...
# Collect item detail item_id: 37088
# ...
# Collect item detail item_id: 37669
# ...
# Collect item detail item_id: 37370
# ...
# Collect item detail item_id: 37051
# ...
# Collect item detail item_id: 37296
# ...
# Collect item detail item_id: 37228
# ...
# Collect item detail item_id: 37214
# ...
# Collect item detail item_id: 37341
# ...
# Collect item detail item_id: 37200
# ...
# Collect item detail item_id: 37191
# ...
# Collect item detail item_id: 37470
# ...
# Collect item detail item_id: 37329
# ...
# Collect item detail item_id: 37221
# ...
# Collect item detail item_id: 37197
# ...
# Collect item detail item_id: 36882
# ...
# Collect item detail item_id: 37446
# ...
# Collect item detail item_id: 37215
# ...
# Collect item detail item_id: 36851
# ...
# Collect item detail item_id: 36791
# ...
# Collect item detail item_id: 37202
# ...
# Collect item detail item_id: 37138
# ...
# Collect item detail item_id: 37118
# ...
# Collect item detail item_id: 35344
# ...
# Collect item detail item_id: 37225
# ...
# Collect item detail item_id: 37121
# ...
# Collect item detail item_id: 36801
# ...
# Collect item detail item_id: 36003
# ...
# Collect item detail item_id: 37120
# ...
# Collect item detail item_id: 37097
# ...
# Collect item detail item_id: 37246
# ...
# Collect item detail item_id: 37099
# ...
# Collect item detail item_id: 36955
# ...
# Collect item detail item_id: 37960
# ...
# Collect item detail item_id: 37247
# ...
# Collect item detail item_id: 37083
# ...
# Collect item detail item_id: 36875
# ...
# Collect item detail item_id: 37227
# ...
# Collect item detail item_id: 37084
# ...
# Collect item detail item_id: 36883
# ...
# Collect item detail item_id: 34387
# ...
# Collect item detail item_id: 36613
# ...
# Collect item detail item_id: 37212
# ...
# Collect item detail item_id: 37077
# ...
# Collect item detail item_id: 37052
# ...
# Collect item detail item_id: 37155
# ...
# Collect item detail item_id: 37007
# ...
# Collect item detail item_id: 36806
# ...
# Collect item detail item_id: 35383
# ...
# Collect item detail item_id: 37193
# ...
# Collect item detail item_id: 37047
# ...
# Collect item detail item_id: 36805
# ...
# Collect item detail item_id: 37041
# ...
# Collect item detail item_id: 36921
# ...
# Collect item detail item_id: 36186
# ...
# Collect item detail item_id: 36969
# ...
# Collect item detail item_id: 36881
# ...
# Collect item detail item_id: 36745
# ...
# Collect item detail item_id: 37219
# ...
# Collect item detail item_id: 36822
# ...
# Collect item detail item_id: 36742
# ...
# Collect item detail item_id: 36925
# ...
# Collect item detail item_id: 36896
# ...
# Collect item detail item_id: 36787
# ...
# Collect item detail item_id: 36689
# ...
# Collect item detail item_id: 36936
# ...
# Collect item detail item_id: 36922
# ...
# Collect item detail item_id: 36782
# ...
# Collect item detail item_id: 36474
# ...
# Collect item detail item_id: 37046
# ...
# Collect item detail item_id: 36916
# ...
# Collect item detail item_id: 36691
# ...
# Collect item detail item_id: 35348
# ...
# Collect item detail item_id: 36990
# ...
# Collect item detail item_id: 36593
# ...
# Collect item detail item_id: 36242
# ...
# Collect item detail item_id: 36566
# ...
# Collect item detail item_id: 36553
# ...
# Collect item detail item_id: 36446
# ...
# Collect item detail item_id: 36604
# ...
# Collect item detail item_id: 36562
# ...
# Collect item detail item_id: 36524
# ...
# Collect item detail item_id: 36612
# ...
# Collect item detail item_id: 36595
# ...
# Collect item detail item_id: 36188
# ...
# Collect item detail item_id: 36560
# ...
# Collect item detail item_id: 36515
# ...
# Collect item detail item_id: 36444
# ...
# Collect item detail item_id: 34436
# ...
# Collect item detail item_id: 36611
# ...
# Collect item detail item_id: 36602
# ...
# Collect item detail item_id: 36224
# ...
# Collect item detail item_id: 36202
# ...
# Collect item detail item_id: 36565
# ...
# Collect item detail item_id: 36455
# ...
# Collect item detail item_id: 36127
# ...
# Collect item detail item_id: 34374
# ...
# Collect item detail item_id: 36511
# ...
# Collect item detail item_id: 36418
# ...
# Collect item detail item_id: 36375
# ...
# Collect item detail item_id: 35274
# ...
# Collect item detail item_id: 36451
# ...
# Collect item detail item_id: 36432
# ...
# Collect item detail item_id: 36320
# ...
# Collect item detail item_id: 36555
# ...
# Collect item detail item_id: 36248
# ...
# Collect item detail item_id: 36198
# ...
# Collect item detail item_id: 36564
# ...
# Collect item detail item_id: 36477
# ...
# Collect item detail item_id: 36218
# ...
# Collect item detail item_id: 34560
# ...
# Collect item detail item_id: 36441
# ...
# Collect item detail item_id: 36364
# ...
# Collect item detail item_id: 34369
# ...
# Collect item detail item_id: 36563
# ...
# Collect item detail item_id: 36352
# ...
# Collect item detail item_id: 34421
# ...
# Collect item detail item_id: 36436
# ...
# Collect item detail item_id: 36184
# ...
# Collect item detail item_id: 36070
# ...
# Collect item detail item_id: 35131
# ...
# Collect item detail item_id: 36245
# ...
# Collect item detail item_id: 36048
# ...
# Collect item detail item_id: 36374
# ...
# Collect item detail item_id: 36149
# ...
# Collect item detail item_id: 36126
# ...
# Collect item detail item_id: 36041
# ...
# Collect item detail item_id: 36409
# ...
# Collect item detail item_id: 36058
# ...
# Collect item detail item_id: 34547
# ...
# Collect item detail item_id: 36225
# ...
# Collect item detail item_id: 35938
# ...
# Collect item detail item_id: 32908
# ...
# Collect item detail item_id: 36220
# ...
# Collect item detail item_id: 36080
# ...
# Collect item detail item_id: 33502
# ...
# Collect item detail item_id: 35967
# ...
# Collect item detail item_id: 36354
# ...
# Collect item detail item_id: 34933
# ...
# Collect item detail item_id: 36141
# ...
# Collect item detail item_id: 36030
# ...
# Collect item detail item_id: 35963
# ...
# Collect item detail item_id: 34582
# ...
# Collect item detail item_id: 36038
# ...
# Collect item detail item_id: 35707
# ...
# Collect item detail item_id: 34541
# ...
# Collect item detail item_id: 33156
# ...
# Collect item detail item_id: 36273
# ...
# Collect item detail item_id: 36148
# ...
# Collect item detail item_id: 35464
# ...
# Collect item detail item_id: 36203
# ...
# Collect item detail item_id: 36073
# ...
# Collect item detail item_id: 36037
# ...
# Collect item detail item_id: 34199
# ...
# Collect item detail item_id: 36170
# ...
# Collect item detail item_id: 36027
# ...
# Collect item detail item_id: 34548
# ...
# Collect item detail item_id: 34335
# ...
# Collect item detail item_id: 35358
# ...
# Collect item detail item_id: 35031
# ...
# Collect item detail item_id: 33432
# ...
# Collect item detail item_id: 33251
# ...
# Collect item detail item_id: 35493
# ...
# Collect item detail item_id: 34889
# ...
# Collect item detail item_id: 35957
# ...
# Collect item detail item_id: 35951
# ...
# Collect item detail item_id: 35412
# ...
# Collect item detail item_id: 36151
# ...
# Collect item detail item_id: 36083
# ...
# Collect item detail item_id: 36047
# ...
# Collect item detail item_id: 35081
# ...
# Collect item detail item_id: 35977
# ...
# Collect item detail item_id: 35922
# ...
# Collect item detail item_id: 34563
# ...
# Collect item detail item_id: 33816
# ...
# Collect item detail item_id: 36111
# ...
# Collect item detail item_id: 35347
# ...
# Collect item detail item_id: 34816
# ...
# Collect item detail item_id: 32873
# ...
# Collect item detail item_id: 35978
# ...
# Collect item detail item_id: 35774
# ...
# Collect item detail item_id: 34772
# ...
# Collect item detail item_id: 33077
# ...
# Collect item detail item_id: 34831
# ...
# Collect item detail item_id: 34575
# ...
# Collect item detail item_id: 33169
# ...
# Collect item detail item_id: 30139
# ...
# Collect item detail item_id: 35102
# ...
# Collect item detail item_id: 34701
# ...
# Collect item detail item_id: 35639
# ...
# Collect item detail item_id: 35385
# ...
# Collect item detail item_id: 34883
# ...
# Collect item detail item_id: 34593
# ...
# Collect item detail item_id: 35462
# ...
# Collect item detail item_id: 34419
# ...
# Collect item detail item_id: 34229
# ...
# Collect item detail item_id: 32102
# ...
# Collect item detail item_id: 35955
# ...
# Collect item detail item_id: 35442
# ...
# Collect item detail item_id: 34412
# ...
# Collect item detail item_id: 33592
# ...
# Collect item detail item_id: 35062
# ...
# Collect item detail item_id: 34785
# ...
# Collect item detail item_id: 34581
# ...
# Collect item detail item_id: 33431
# ...
# Collect item detail item_id: 35537
# ...
# Collect item detail item_id: 35403
# ...
# Collect item detail item_id: 34713
# ...
# Collect item detail item_id: 32835
# ...
# Collect item detail item_id: 35343
# ...
# Collect item detail item_id: 34572
# ...
# Collect item detail item_id: 34381
# ...
# Collect item detail item_id: 33430
# ...
# Collect item detail item_id: 34931
# ...
# Collect item detail item_id: 34448
# ...
# Collect item detail item_id: 35069
# ...
# Collect item detail item_id: 34807
# ...
# Collect item detail item_id: 34509
# ...
# Collect item detail item_id: 33044
# ...
# Collect item detail item_id: 35370
# ...
# Collect item detail item_id: 34294
# ...
# Collect item detail item_id: 33093
# ...
# Collect item detail item_id: 26735
# ...
# Collect item detail item_id: 34992
# ...
# Collect item detail item_id: 34670
# ...
# Collect item detail item_id: 32416
# ...
# Collect item detail item_id: 34414
# ...
# Collect item detail item_id: 35332
# ...
# Collect item detail item_id: 34884
# ...
# Collect item detail item_id: 32728
# ...
# Collect item detail item_id: 35179
# ...
# Collect item detail item_id: 35058
# ...
# Collect item detail item_id: 34226
# ...
# Collect item detail item_id: 32238
# ...
# Collect item detail item_id: 34885
# ...
# Collect item detail item_id: 34545
# ...
# Collect item detail item_id: 34227
# ...
# Collect item detail item_id: 34105
# ...
# Collect item detail item_id: 33622
# ...
# Collect item detail item_id: 34573
# ...
# Collect item detail item_id: 34060
# ...
# Collect item detail item_id: 33889
# ...
# Collect item detail item_id: 34640
# ...
# Collect item detail item_id: 34506
# ...
# Collect item detail item_id: 34321
# ...
# Collect item detail item_id: 34160
# ...
# Collect item detail item_id: 34382
# ...
# Collect item detail item_id: 34364
# ...
# Collect item detail item_id: 33518
# ...
# Collect item detail item_id: 34580
# ...
# Collect item detail item_id: 33619
# ...
# Collect item detail item_id: 33468
# ...
# Collect item detail item_id: 32874
# ...
# Collect item detail item_id: 34643
# ...
# Collect item detail item_id: 33737
# ...
# Collect item detail item_id: 33662
# ...
# Collect item detail item_id: 33042
# ...
# Collect item detail item_id: 34886
# ...
# Collect item detail item_id: 34583
# ...
# Collect item detail item_id: 33639
# ...
# Collect item detail item_id: 31628
# ...
# Collect item detail item_id: 34445
# ...
# Collect item detail item_id: 34171
# ...
# Collect item detail item_id: 33521
# ...
# Collect item detail item_id: 32686
# ...
# Collect item detail item_id: 34018
# ...
# Collect item detail item_id: 33944
# ...
# Collect item detail item_id: 33141
# ...
# Collect item detail item_id: 34574
# ...
# Collect item detail item_id: 34228
# ...
# Collect item detail item_id: 33500
# ...
# Collect item detail item_id: 33041
# ...
# Collect item detail item_id: 34248
# ...
# Collect item detail item_id: 34159
# ...
# Collect item detail item_id: 34104
# ...
# Collect item detail item_id: 33021
# ...
# Collect item detail item_id: 34064
# ...
# Collect item detail item_id: 33995
# ...
# Collect item detail item_id: 33505
# ...
# Collect item detail item_id: 32918
# ...
# Collect item detail item_id: 33823
# ...
# Collect item detail item_id: 33396
# ...
# Collect item detail item_id: 33365
# ...
# Collect item detail item_id: 33317
# ...
# Collect item detail item_id: 34408
# ...
# Collect item detail item_id: 34173
# ...
# Collect item detail item_id: 32942
# ...
# Collect item detail item_id: 32876
# ...
# Collect item detail item_id: 33230
# ...
# Collect item detail item_id: 33111
# ...
# Collect item detail item_id: 32963
# ...
# Collect item detail item_id: 32863
# ...
# Collect item detail item_id: 29846
# ...
# Collect item detail item_id: 33514
# ...
# Collect item detail item_id: 33160
# ...
# Collect item detail item_id: 34342
# ...
# Collect item detail item_id: 33249
# ...
# Collect item detail item_id: 33080
# ...
# Collect item detail item_id: 32941
# ...
# Collect item detail item_id: 33780
# ...
# Collect item detail item_id: 33520
# ...
# Collect item detail item_id: 33246
# ...
# Collect item detail item_id: 31175
# ...
# Collect item detail item_id: 33062
# ...
# Collect item detail item_id: 33646
# ...
# Collect item detail item_id: 32287
# ...
# Collect item detail item_id: 33741
# ...
# Collect item detail item_id: 33328
# ...
# Collect item detail item_id: 32944
# ...
# Collect item detail item_id: 32838
# ...
# Collect item detail item_id: 33937
# ...
# Collect item detail item_id: 33126
# ...
# Collect item detail item_id: 33043
# ...
# Collect item detail item_id: 32848
# ...
# Collect item detail item_id: 32943
# ...
# Collect item detail item_id: 32910
# ...
# Collect item detail item_id: 33274
# ...
# Collect item detail item_id: 32913
# ...
# Collect item detail item_id: 32760
# ...
# Collect item detail item_id: 32065
# ...
# Collect item detail item_id: 33740
# ...
# Collect item detail item_id: 33134
# ...
# Collect item detail item_id: 32861
# ...
# Collect item detail item_id: 33090
# ...
# Collect item detail item_id: 32921
# ...
# Collect item detail item_id: 32167
# ...
# Collect item detail item_id: 31481
# ...
# Collect item detail item_id: 32977
# ...
# Collect item detail item_id: 33122
# ...
# Collect item detail item_id: 32993
# ...
# Collect item detail item_id: 31278
# ...
# Collect item detail item_id: 33222
# ...
# Collect item detail item_id: 32946
# ...
# Collect item detail item_id: 32888
# ...
# Collect item detail item_id: 32135
# ...
# Collect item detail item_id: 33010
# ...
# Collect item detail item_id: 32917
# ...
# Collect item detail item_id: 32152
# ...
# Collect item detail item_id: 32945
# ...
# Collect item detail item_id: 32795
# ...
# Collect item detail item_id: 32850
# ...
# Collect item detail item_id: 32656
# ...
# Collect item detail item_id: 22608
# ...
# Collect item detail item_id: 32906
# ...
# Collect item detail item_id: 32800
# ...
# Collect item detail item_id: 32485
# ...
# Collect item detail item_id: 31298
# ...
# Collect item detail item_id: 32887
# ...
# Collect item detail item_id: 32657
# ...
# Collect item detail item_id: 32166
# ...
# Collect item detail item_id: 30792
# ...
# Collect item detail item_id: 33157
# ...
# Collect item detail item_id: 32626
# ...
# Collect item detail item_id: 32158
# ...
# Collect item detail item_id: 30383
# ...
# Collect item detail item_id: 32663
# ...
# Collect item detail item_id: 32662
# ...
# Collect item detail item_id: 32622
# ...
# Collect item detail item_id: 31109
# ...
# Collect item detail item_id: 32743
# ...
# Collect item detail item_id: 32846
# ...
# Collect item detail item_id: 32466
# ...
# Collect item detail item_id: 31039
# ...
# Collect item detail item_id: 33087
# ...
# Collect item detail item_id: 32412
# ...
# Collect item detail item_id: 32037
# ...
# Collect item detail item_id: 32489
# ...
# Collect item detail item_id: 32211
# ...
# Collect item detail item_id: 32159
# ...
# Collect item detail item_id: 32171
# ...
# Collect item detail item_id: 32160
# ...
# Collect item detail item_id: 31942
# ...
# Collect item detail item_id: 32486
# ...
# Collect item detail item_id: 32257
# ...
# Collect item detail item_id: 32210
# ...
# Collect item detail item_id: 30787
# ...
# Collect item detail item_id: 32248
# ...
# Collect item detail item_id: 32206
# ...
# Collect item detail item_id: 32194
# ...
# Collect item detail item_id: 31766
# ...
# Collect item detail item_id: 33106
# ...
# Collect item detail item_id: 32510
# ...
# Collect item detail item_id: 31934
# ...
# Collect item detail item_id: 31135
# ...
# Collect item detail item_id: 33243
# ...
# Collect item detail item_id: 32646
# ...
# Collect item detail item_id: 32035
# ...
# Collect item detail item_id: 31301
# ...
# Collect item detail item_id: 32667
# ...
# Collect item detail item_id: 32731
# ...
# Collect item detail item_id: 31749
# ...
# Collect item detail item_id: 31507
# ...
# Collect item detail item_id: 31468
# ...
# Collect item detail item_id: 14153
# ...
# Collect item detail item_id: 32068
# ...
# Collect item detail item_id: 31649
# ...
# Collect item detail item_id: 31566
# ...
# Collect item detail item_id: 31173
# ...
# Collect item detail item_id: 32113
# ...
# Collect item detail item_id: 32026
# ...
# Collect item detail item_id: 31720
# ...
# Collect item detail item_id: 30831
# ...
# Collect item detail item_id: 32118
# ...
# Collect item detail item_id: 31939
# ...
# Collect item detail item_id: 31200
# ...
# Collect item detail item_id: 27618
# ...
# Collect item detail item_id: 32652
# ...
# Collect item detail item_id: 32101
# ...
# Collect item detail item_id: 31626
# ...
# Collect item detail item_id: 31359
# ...
# Collect item detail item_id: 32178
# ...
# Collect item detail item_id: 32912
# ...
# Collect item detail item_id: 32134
# ...
# Collect item detail item_id: 30750
# ...
# Collect item detail item_id: 32058
# ...
# Collect item detail item_id: 22317
# ...
# Collect item detail item_id: 32075
# ...
# Collect item detail item_id: 31177
# ...
# Collect item detail item_id: 30691
# ...
# Collect item detail item_id: 30107
# ...
# Collect item detail item_id: 32309
# ...
# Collect item detail item_id: 31624
# ...
# Collect item detail item_id: 31283
# ...
# Collect item detail item_id: 30966
# ...
# Collect item detail item_id: 31699
# ...
# Collect item detail item_id: 31501
# ...
# Collect item detail item_id: 31174
# ...
# Collect item detail item_id: 31004
# ...
# Collect item detail item_id: 31654
# ...
# Collect item detail item_id: 31358
# ...
# Collect item detail item_id: 30964
# ...
# Collect item detail item_id: 30480
# ...
# Collect item detail item_id: 31556
# ...
# Collect item detail item_id: 31503
# ...
# Collect item detail item_id: 30930
# ...
# Collect item detail item_id: 30355
# ...
# Collect item detail item_id: 31294
# ...
# Collect item detail item_id: 31154
# ...
# Collect item detail item_id: 31554
# ...
# Collect item detail item_id: 31296
# ...
# Collect item detail item_id: 31400
# ...
# Collect item detail item_id: 31437
# ...
# Collect item detail item_id: 30789
# ...
# Collect item detail item_id: 30464
# ...
# Collect item detail item_id: 31326
# ...
# Collect item detail item_id: 30906
# ...
# Collect item detail item_id: 30879
# ...
# Collect item detail item_id: 29945
# ...
# Collect item detail item_id: 31282
# ...
# Collect item detail item_id: 31061
# ...
# Collect item detail item_id: 30871
# ...
# Collect item detail item_id: 30542
# ...
# Collect item detail item_id: 31573
# ...
# Collect item detail item_id: 31155
# ...
# Collect item detail item_id: 30783
# ...
# Collect item detail item_id: 30748
# ...
# Collect item detail item_id: 31189
# ...
# Collect item detail item_id: 31134
# ...
# Collect item detail item_id: 30862
# ...
# Collect item detail item_id: 30633
# ...
# Collect item detail item_id: 31112
# ...
# Collect item detail item_id: 31031
# ...
# Collect item detail item_id: 30967
# ...
# Collect item detail item_id: 30238
# ...
# Collect item detail item_id: 30990
# ...
# Collect item detail item_id: 30892
# ...
# Collect item detail item_id: 30708
# ...
# Collect item detail item_id: 30277
# ...
# Collect item detail item_id: 30811
# ...
# Collect item detail item_id: 30755
# ...
# Collect item detail item_id: 30676
# ...
# Collect item detail item_id: 30589
# ...
# Collect item detail item_id: 31087
# ...
# Collect item detail item_id: 30756
# ...
# Collect item detail item_id: 30603
# ...
# Collect item detail item_id: 30233
# ...
# Collect item detail item_id: 30905
# ...
# Collect item detail item_id: 30859
# ...
# Collect item detail item_id: 30754
# ...
# Collect item detail item_id: 30572
# ...
# Collect item detail item_id: 30734
# ...
# Collect item detail item_id: 30690
# ...
# Collect item detail item_id: 30379
# ...
# Collect item detail item_id: 29723
# ...
# Collect item detail item_id: 30823
# ...
# Collect item detail item_id: 30573
# ...
# Collect item detail item_id: 30570
# ...
# Collect item detail item_id: 30118
# ...
# Collect item detail item_id: 30918
# ...
# Collect item detail item_id: 30907
# ...
# Collect item detail item_id: 30604
# ...
# Collect item detail item_id: 30575
# ...
# Collect item detail item_id: 30271
# ...
# Collect item detail item_id: 30164
# ...
# Collect item detail item_id: 29848
# ...
# Collect item detail item_id: 30608
# ...
# Collect item detail item_id: 30497
# ...
# Collect item detail item_id: 30189
# ...
# Collect item detail item_id: 29745
# ...
# Collect item detail item_id: 30668
# ...
# Collect item detail item_id: 30593
# ...
# Collect item detail item_id: 30580
# ...
# Collect item detail item_id: 30119
# ...
# Collect item detail item_id: 30624
# ...
# Collect item detail item_id: 30602
# ...
# Collect item detail item_id: 30468
# ...
# Collect item detail item_id: 30409
# ...
# Collect item detail item_id: 30630
# ...
# Collect item detail item_id: 30249
# ...
# Collect item detail item_id: 30239
# ...
# Collect item detail item_id: 29752
# ...
# Collect item detail item_id: 30671
# ...
# Collect item detail item_id: 30242
# ...
# Collect item detail item_id: 30184
# ...
# Collect item detail item_id: 29950
# ...
# Collect item detail item_id: 30636
# ...
# Collect item detail item_id: 30205
# ...
# Collect item detail item_id: 30125
# ...
# Collect item detail item_id: 29953
# ...
# Collect item detail item_id: 30577
# ...
# Collect item detail item_id: 30496
# ...
# Collect item detail item_id: 28510
# ...
# Collect item detail item_id: 30273
# ...
# Collect item detail item_id: 30110
# ...
# Collect item detail item_id: 30090
# ...
# Collect item detail item_id: 30044
# ...
# Collect item detail item_id: 30257
# ...
# Collect item detail item_id: 30127
# ...
# Collect item detail item_id: 29943
# ...
# Collect item detail item_id: 26914
# ...
# Collect item detail item_id: 30354
# ...
# Collect item detail item_id: 30247
# ...
# Collect item detail item_id: 30241
# ...
# Collect item detail item_id: 30017
# ...
# Collect item detail item_id: 30269
# ...
# Collect item detail item_id: 30193
# ...
# Collect item detail item_id: 29927
# ...
# Collect item detail item_id: 29880
# ...
# Collect item detail item_id: 30190
# ...
# Collect item detail item_id: 30027
# ...
# Collect item detail item_id: 29866
# ...
# Collect item detail item_id: 30256
# ...
# Collect item detail item_id: 30255
# ...
# Collect item detail item_id: 30252
# ...
# Collect item detail item_id: 29989
# ...
# Collect item detail item_id: 29973
# ...
# Collect item detail item_id: 30571
# ...
# Collect item detail item_id: 30435
# ...
# Collect item detail item_id: 30032
# ...
# Collect item detail item_id: 29789
# ...
# Collect item detail item_id: 29942
# ...
# Collect item detail item_id: 30006
# ...
# Collect item detail item_id: 29995
# ...
# Collect item detail item_id: 28784
# ...
# Collect item detail item_id: 30250
# ...
# Collect item detail item_id: 29847
# ...
# Collect item detail item_id: 28234
# ...
# Collect item detail item_id: 26455
# ...
# Collect item detail item_id: 30601
# ...
# Collect item detail item_id: 30004
# ...
# Collect item detail item_id: 29974
# ...
# Collect item detail item_id: 29063
# ...
# Collect item detail item_id: 30008
# ...
# Collect item detail item_id: 29975
# ...
# Collect item detail item_id: 29814
# ...
# Collect item detail item_id: 29424
# ...
# Collect item detail item_id: 29901
# ...
# Collect item detail item_id: 29778
# ...
# Collect item detail item_id: 29699
# ...
# Collect item detail item_id: 26585
# ...
# Collect item detail item_id: 29913
# ...
# Collect item detail item_id: 29879
# ...
# Collect item detail item_id: 29185
# ...
# Collect item detail item_id: 27763
# ...
# Collect item detail item_id: 29728
# ...
# Collect item detail item_id: 29219
# ...
# Collect item detail item_id: 29724
# ...
# Collect item detail item_id: 29562
# ...
# Collect item detail item_id: 29423
# ...
# Collect item detail item_id: 29396
# ...
# Collect item detail item_id: 29528
# ...
# Collect item detail item_id: 29261
# ...
# Collect item detail item_id: 30180
# ...
# Collect item detail item_id: 29811
# ...
# Collect item detail item_id: 29597
# ...
# Collect item detail item_id: 26545
# ...
# Collect item detail item_id: 29887
# ...
# Collect item detail item_id: 29561
# ...
# Collect item detail item_id: 28868
# ...
# Collect item detail item_id: 28426
# ...
# Collect item detail item_id: 29829
# ...
# Collect item detail item_id: 29685
# ...
# Collect item detail item_id: 29486
# ...
# Collect item detail item_id: 28427
# ...
# Collect item detail item_id: 28920
# ...
# Collect item detail item_id: 29713
# ...
# Collect item detail item_id: 29164
# ...
# Collect item detail item_id: 27735
# ...
# Collect item detail item_id: 29510
# ...
# Collect item detail item_id: 27360
# ...
# Collect item detail item_id: 29358
# ...
# Collect item detail item_id: 27090
# ...
# Collect item detail item_id: 28878
# ...
# Collect item detail item_id: 27180
# ...
# Collect item detail item_id: 29522
# ...
# Collect item detail item_id: 28748
# ...
# Collect item detail item_id: 27312
# ...
# Collect item detail item_id: 15863
# ...
# Collect item detail item_id: 29517
# ...
# Collect item detail item_id: 28861
# ...
# Collect item detail item_id: 27630
# ...
# Collect item detail item_id: 26840
# ...
# Collect item detail item_id: 29213
# ...
# Collect item detail item_id: 29529
# ...
# Collect item detail item_id: 29218
# ...
# Collect item detail item_id: 28042
# ...
# Collect item detail item_id: 28943
# ...
# Collect item detail item_id: 28941
# ...
# Collect item detail item_id: 28112
# ...
# Collect item detail item_id: 29097
# ...
# Collect item detail item_id: 28669
# ...
# Collect item detail item_id: 28052
# ...
# Collect item detail item_id: 23355
# ...
# Collect item detail item_id: 28772
# ...
# Collect item detail item_id: 26786
# ...
# Collect item detail item_id: 26549
# ...
# Collect item detail item_id: 28794
# ...
# Collect item detail item_id: 29018
# ...
# Collect item detail item_id: 28912
# ...
# Collect item detail item_id: 28023
# ...
# Collect item detail item_id: 28287
# ...
# Collect item detail item_id: 28249
# ...
# Collect item detail item_id: 27368
# ...
# Collect item detail item_id: 27289
# ...
# Collect item detail item_id: 29064
# ...
# Collect item detail item_id: 28877
# ...
# Collect item detail item_id: 28241
# ...
# Collect item detail item_id: 27488
# ...
# Collect item detail item_id: 29115
# ...
# Collect item detail item_id: 28504
# ...
# Collect item detail item_id: 27681
# ...
# Collect item detail item_id: 26105
# ...
# Collect item detail item_id: 28384
# ...
# Collect item detail item_id: 28045
# ...
# Collect item detail item_id: 27741
# ...
# Collect item detail item_id: 26681
# ...
# Collect item detail item_id: 29017
# ...
# Collect item detail item_id: 27764
# ...
# Collect item detail item_id: 27582
# ...
# Collect item detail item_id: 26552
# ...
# Collect item detail item_id: 29258
# ...
# Collect item detail item_id: 26877
# ...
# Collect item detail item_id: 26778
# ...
# Collect item detail item_id: 27796
# ...
# Collect item detail item_id: 26848
# ...
# Collect item detail item_id: 27666
# ...
# Collect item detail item_id: 27470
# ...
# Collect item detail item_id: 26421
# ...
# Collect item detail item_id: 25677
# ...
# Collect item detail item_id: 27642
# ...
# Collect item detail item_id: 27484
# ...
# Collect item detail item_id: 27364
# ...
# Collect item detail item_id: 26127
# ...
# Collect item detail item_id: 27699
# ...
# Collect item detail item_id: 27611
# ...
# Collect item detail item_id: 27267
# ...
# Collect item detail item_id: 25291
# ...
# Collect item detail item_id: 27570
# ...
# Collect item detail item_id: 27351
# ...
# Collect item detail item_id: 27328
# ...
# Collect item detail item_id: 25565
# ...
# Collect item detail item_id: 29744
# ...
# Collect item detail item_id: 27675
# ...
# Collect item detail item_id: 26554
# ...
# Collect item detail item_id: 27055
# ...
# Collect item detail item_id: 26679
# ...
# Collect item detail item_id: 26960
# ...
# Collect item detail item_id: 26361
# ...
# Collect item detail item_id: 23869
# ...
# Collect item detail item_id: 27421
# ...
# Collect item detail item_id: 27066
# ...
# Collect item detail item_id: 26548
# ...
# Collect item detail item_id: 27181
# ...
# Collect item detail item_id: 27112
# ...
# Collect item detail item_id: 26843
# ...
# Collect item detail item_id: 24977
# ...
# Collect item detail item_id: 27357
# ...
# Collect item detail item_id: 27182
# ...
# Collect item detail item_id: 26415
# ...
# Collect item detail item_id: 25610
# ...
# Collect item detail item_id: 26649
# ...
# Collect item detail item_id: 27190
# ...
# Collect item detail item_id: 27110
# ...
# Collect item detail item_id: 26304
# ...
# Collect item detail item_id: 27024
# ...
# Collect item detail item_id: 26939
# ...
# Collect item detail item_id: 26305
# ...
# Collect item detail item_id: 25498
# ...
# Collect item detail item_id: 28020
# ...
# Collect item detail item_id: 26964
# ...
# Collect item detail item_id: 26419
# ...
# Collect item detail item_id: 25735
# ...
# Collect item detail item_id: 28113
# ...
# Collect item detail item_id: 26362
# ...
# Collect item detail item_id: 24853
# ...
# Collect item detail item_id: 26499
# ...
# Collect item detail item_id: 26140
# ...
# Collect item detail item_id: 14594
# ...
# Collect item detail item_id: 26777
# ...
# Collect item detail item_id: 26508
# ...
# Collect item detail item_id: 26111
# ...
# Collect item detail item_id: 26012
# ...
# Collect item detail item_id: 26619
# ...
# Collect item detail item_id: 25734
# ...
# Collect item detail item_id: 25628
# ...
# Collect item detail item_id: 24869
# ...
# Collect item detail item_id: 26550
# ...
# Collect item detail item_id: 26453
# ...
# Collect item detail item_id: 25731
# ...
# Collect item detail item_id: 24835
# ...
# Collect item detail item_id: 26680
# ...
# Collect item detail item_id: 26485
# ...
# Collect item detail item_id: 24870
# ...
# Collect item detail item_id: 26118
# ...
# Collect item detail item_id: 26413
# ...
# Collect item detail item_id: 26022
# ...
# Collect item detail item_id: 24899
# ...
# Collect item detail item_id: 25819
# ...
# Collect item detail item_id: 25451
# ...
# Collect item detail item_id: 26096
# ...
# Collect item detail item_id: 25722
# ...
# Collect item detail item_id: 25573
# ...
# Collect item detail item_id: 24386
# ...
# Collect item detail item_id: 25921
# ...
# Collect item detail item_id: 26303
# ...
# Collect item detail item_id: 25365
# ...
# Collect item detail item_id: 24578
# ...
# Collect item detail item_id: 26132
# ...
# Collect item detail item_id: 25755
# ...
# Collect item detail item_id: 24842
# ...
# Collect item detail item_id: 26375
# ...
# Collect item detail item_id: 26090
# ...
# Collect item detail item_id: 25321
# ...
# Collect item detail item_id: 24262
# ...
# Collect item detail item_id: 25614
# ...
# Collect item detail item_id: 25363
# ...
# Collect item detail item_id: 25317
# ...
# Collect item detail item_id: 26277
# ...
# Collect item detail item_id: 24867
# ...
# Collect item detail item_id: 24229
# ...
# Collect item detail item_id: 24159
# ...
# Collect item detail item_id: 26348
# ...
# Collect item detail item_id: 25478
# ...
# Collect item detail item_id: 24706
# ...
# Collect item detail item_id: 25465
# ...
# Collect item detail item_id: 24863
# ...
# Collect item detail item_id: 23349
# ...
# Collect item detail item_id: 12635
# ...
# Collect item detail item_id: 25675
# ...
# Collect item detail item_id: 25079
# ...
# Collect item detail item_id: 24450
# ...
# Collect item detail item_id: 24169
# ...
# Collect item detail item_id: 25395
# ...
# Collect item detail item_id: 24385
# ...
# Collect item detail item_id: 24265
# ...
# Collect item detail item_id: 24082
# ...
# Collect item detail item_id: 24256
# ...
# Collect item detail item_id: 24973
# ...
# Collect item detail item_id: 24314
# ...
# Collect item detail item_id: 25295
# ...
# Collect item detail item_id: 24264
# ...
# Collect item detail item_id: 24222
# ...
# Collect item detail item_id: 24221
# ...
# Collect item detail item_id: 24111
# ...
# Collect item detail item_id: 24172
# ...
# Collect item detail item_id: 25200
# ...
# Collect item detail item_id: 24224
# ...
# Collect item detail item_id: 25646
# ...
# Collect item detail item_id: 24745
# ...
# Collect item detail item_id: 23899
# ...
# Collect item detail item_id: 23870
# ...
# Collect item detail item_id: 24898
# ...
# Collect item detail item_id: 24866
# ...
# Collect item detail item_id: 23909
# ...
# Collect item detail item_id: 24956
# ...
# Collect item detail item_id: 24076
# ...
# Collect item detail item_id: 23784
# ...
# Collect item detail item_id: 23689
# ...
# Collect item detail item_id: 24570
# ...
# Collect item detail item_id: 23961
# ...
# Collect item detail item_id: 23920
# ...
# Collect item detail item_id: 23408
# ...
# Collect item detail item_id: 24220
# ...
# Collect item detail item_id: 23721
# ...
# Collect item detail item_id: 23697
# ...
# Collect item detail item_id: 21646
# ...
# Collect item detail item_id: 24389
# ...
# Collect item detail item_id: 23781
# ...
# Collect item detail item_id: 23690
# ...
# Collect item detail item_id: 24384
# ...
# Collect item detail item_id: 24064
# ...
# Collect item detail item_id: 23796
# ...
# Collect item detail item_id: 23665
# ...
# Collect item detail item_id: 24695
# ...
# Collect item detail item_id: 24223
# ...
# Collect item detail item_id: 23688
# ...
# Collect item detail item_id: 23728
# ...
# Collect item detail item_id: 23380
# ...
# Collect item detail item_id: 22297
# ...
# Collect item detail item_id: 22334
# ...
# Collect item detail item_id: 24258
# ...
# Collect item detail item_id: 23802
# ...
# Collect item detail item_id: 21951
# ...
# Collect item detail item_id: 24180
# ...
# Collect item detail item_id: 23783
# ...
# Collect item detail item_id: 23739
# ...
# Collect item detail item_id: 23478
# ...
# Collect item detail item_id: 23782
# ...
# Collect item detail item_id: 23599
# ...
# Collect item detail item_id: 22274
# ...
# Collect item detail item_id: 21977
# ...
# Collect item detail item_id: 23775
# ...
# Collect item detail item_id: 23852
# ...
# Collect item detail item_id: 23968
# ...
# Collect item detail item_id: 23222
# ...
# Collect item detail item_id: 23864
# ...
# Collect item detail item_id: 23619
# ...
# Collect item detail item_id: 23590
# ...
# Collect item detail item_id: 22849
# ...
# Collect item detail item_id: 23871
# ...
# Collect item detail item_id: 23480
# ...
# Collect item detail item_id: 22824
# ...
# Collect item detail item_id: 23526
# ...
# Collect item detail item_id: 22813
# ...
# Collect item detail item_id: 19527
# ...
# Collect item detail item_id: 23351
# ...
# Collect item detail item_id: 23657
# ...
# Collect item detail item_id: 23489
# ...
# Collect item detail item_id: 21760
# ...
# Collect item detail item_id: 21492
# ...
# Collect item detail item_id: 22075
# ...
# Collect item detail item_id: 23774
# ...
# Collect item detail item_id: 23506
# ...
# Collect item detail item_id: 22314
# ...
# Collect item detail item_id: 22193
# ...
# Collect item detail item_id: 23479
# ...
# Collect item detail item_id: 23447
# ...
# Collect item detail item_id: 22653
# ...
# Collect item detail item_id: 21979
# ...
# Collect item detail item_id: 23594
# ...
# Collect item detail item_id: 23560
# ...
# Collect item detail item_id: 21639
# ...
# Collect item detail item_id: 23061
# ...
# Collect item detail item_id: 23133
# ...
# Collect item detail item_id: 23407
# ...
# Collect item detail item_id: 21490
# ...
# Collect item detail item_id: 23354
# ...
# Collect item detail item_id: 21484
# ...
# Collect item detail item_id: 23504
# ...
# Collect item detail item_id: 22490
# ...
# Collect item detail item_id: 21814
# ...
# Collect item detail item_id: 23350
# ...
# Collect item detail item_id: 22348
# ...
# Collect item detail item_id: 21543
# ...
# Collect item detail item_id: 20689
# ...
# Collect item detail item_id: 21483
# ...
# Collect item detail item_id: 22943
# ...
# Collect item detail item_id: 21990
# ...
# Collect item detail item_id: 22285
# ...
# Collect item detail item_id: 21866
# ...
# Collect item detail item_id: 21328
# ...
# Collect item detail item_id: 21272
# ...
# Collect item detail item_id: 22248
# ...
# Collect item detail item_id: 22255
# ...
# Collect item detail item_id: 21758
# ...
# Collect item detail item_id: 21491
# ...
# Collect item detail item_id: 22965
# ...
# Collect item detail item_id: 21800
# ...
# Collect item detail item_id: 22632
# ...
# Collect item detail item_id: 20780
# ...
# Collect item detail item_id: 20660
# ...
# Collect item detail item_id: 22301
# ...
# Collect item detail item_id: 20841
# ...
# Collect item detail item_id: 22654
# ...
# Collect item detail item_id: 21830
# ...
# Collect item detail item_id: 21489
# ...
# Collect item detail item_id: 22335
# ...
# Collect item detail item_id: 22919
# ...
# Collect item detail item_id: 21110
# ...
# Collect item detail item_id: 22431
# ...
# Collect item detail item_id: 21815
# ...
# Collect item detail item_id: 20782
# ...
# Collect item detail item_id: 19096
# ...
# Collect item detail item_id: 22222
# ...
# Collect item detail item_id: 21680
# ...
# Collect item detail item_id: 21159
# ...
# Collect item detail item_id: 20806
# ...
# Collect item detail item_id: 21852
# ...
# Collect item detail item_id: 19918
# ...
# Collect item detail item_id: 22250
# ...
# Collect item detail item_id: 20842
# ...
# Collect item detail item_id: 20485
# ...
# Collect item detail item_id: 22254
# ...
# Collect item detail item_id: 22249
# ...
# Collect item detail item_id: 20578
# ...
# Collect item detail item_id: 22144
# ...
# Collect item detail item_id: 21848
# ...
# Collect item detail item_id: 20810
# ...
# Collect item detail item_id: 20809
# ...
# Collect item detail item_id: 22092
# ...
# Collect item detail item_id: 21695
# ...
# Collect item detail item_id: 20811
# ...
# Collect item detail item_id: 20546
# ...
# Collect item detail item_id: 21842
# ...
# Collect item detail item_id: 21835
# ...
# Collect item detail item_id: 20961
# ...
# Collect item detail item_id: 20532
# ...
# Collect item detail item_id: 21757
# ...
# Collect item detail item_id: 21439
# ...
# Collect item detail item_id: 20237
# ...
# Collect item detail item_id: 20081
# ...
# Collect item detail item_id: 22179
# ...
# Collect item detail item_id: 21741
# ...
# Collect item detail item_id: 20978
# ...
# Collect item detail item_id: 20904
# ...
# Collect item detail item_id: 21801
# ...
# Collect item detail item_id: 20374
# ...
# Collect item detail item_id: 19298
# ...
# Collect item detail item_id: 17094
# ...
# Collect item detail item_id: 21915
# ...
# Collect item detail item_id: 21645
# ...
# Collect item detail item_id: 19816
# ...
# Collect item detail item_id: 21759
# ...
# Collect item detail item_id: 21377
# ...
# Collect item detail item_id: 19761
# ...
# Collect item detail item_id: 19657
# ...
# Collect item detail item_id: 21765
# ...
# Collect item detail item_id: 21618
# ...
# Collect item detail item_id: 20502
# ...
# Collect item detail item_id: 17175
# ...
# Collect item detail item_id: 21106
# ...
# Collect item detail item_id: 21298
# ...
# Collect item detail item_id: 19189
# ...
# Collect item detail item_id: 18177
# ...
# Collect item detail item_id: 18678
# ...
# Collect item detail item_id: 21375
# ...
# Collect item detail item_id: 20960
# ...
# Collect item detail item_id: 20043
# ...
# Collect item detail item_id: 21480
# ...
# Collect item detail item_id: 21239
# ...
# Collect item detail item_id: 21109
# ...
# Collect item detail item_id: 21623
# ...
# Collect item detail item_id: 16456
# ...
# Collect item detail item_id: 14543
# ...
# Collect item detail item_id: 21582
# ...
# Collect item detail item_id: 18959
# ...
# Collect item detail item_id: 21508
# ...
# Collect item detail item_id: 21229
# ...
# Collect item detail item_id: 20240
# ...
# Collect item detail item_id: 19650
# ...
# Collect item detail item_id: 21539
# ...
# Collect item detail item_id: 21422
# ...
# Collect item detail item_id: 20280
# ...
# Collect item detail item_id: 19915
# ...
# Collect item detail item_id: 21448
# ...
# Collect item detail item_id: 21325
# ...
# Collect item detail item_id: 19563
# ...
# Collect item detail item_id: 21326
# ...
# Collect item detail item_id: 21482
# ...
# Collect item detail item_id: 19889
# ...
# Collect item detail item_id: 19842
# ...
# Collect item detail item_id: 16916
# ...
# ...
# ...
# Collect item detail item_id: 1613
# ...
# Collect item detail item_id: 1609
# ...
# Collect item detail item_id: 1603
# ...
# Collect item detail item_id: 1601
# ...
# Collect item detail item_id: 1598
# ...
# Collect item detail item_id: 1597
# ...
# Collect item detail item_id: 1596
# ...
# Collect item detail item_id: 1591
# ...
# Collect item detail item_id: 1589
# ...
# Collect item detail item_id: 1584
# ...
# Collect item detail item_id: 1581
# ...
# Collect item detail item_id: 1580
# ...
# Collect item detail item_id: 1578
# ...
# Collect item detail item_id: 1577
# ...
# Collect item detail item_id: 1576
# ...
# Collect item detail item_id: 1575
# ...
# Collect item detail item_id: 1571
# ...
# Collect item detail item_id: 1568
# ...
# Collect item detail item_id: 1563
# ...
# Collect item detail item_id: 1559
# ...
# Collect item detail item_id: 1557
# ...
# Collect item detail item_id: 1556
# ...
# Collect item detail item_id: 1552
# ...
# Collect item detail item_id: 1551
# ...
# Collect item detail item_id: 1550
# ...
# Collect item detail item_id: 1549
# ...
# Collect item detail item_id: 1548
# ...
# Collect item detail item_id: 1545
# ...
# Collect item detail item_id: 1544
# ...
# Collect item detail item_id: 1542
# ...
# Collect item detail item_id: 1539
# ...
# Collect item detail item_id: 1537
# ...
# Collect item detail item_id: 1535
# ...
# Collect item detail item_id: 1532
# ...
# Collect item detail item_id: 1528
# ...
# Collect item detail item_id: 1523
# ...
# Collect item detail item_id: 1522
# ...
# Collect item detail item_id: 1520
# ...
# Collect item detail item_id: 1519
# ...
# Collect item detail item_id: 1518
# ...
# Collect item detail item_id: 1515
# ...
# Collect item detail item_id: 1514
# ...
# Collect item detail item_id: 1513
# ...
# Collect item detail item_id: 1510
# ...
# Collect item detail item_id: 1509
# ...
# Collect item detail item_id: 1508
# ...
# Collect item detail item_id: 1504
# ...
# Collect item detail item_id: 1495
# ...
# Collect item detail item_id: 1492
# ...
# Collect item detail item_id: 1491
# ...
# Collect item detail item_id: 1489
# ...
# Collect item detail item_id: 1488
# ...
# Collect item detail item_id: 1487
# ...
# Collect item detail item_id: 1484
# ...
# Collect item detail item_id: 1479
# ...
# Collect item detail item_id: 1476
# ...
# Collect item detail item_id: 1473
# ...
# Collect item detail item_id: 1472
# ...
# Collect item detail item_id: 1471
# ...
# Collect item detail item_id: 1466
# ...
# Collect item detail item_id: 1470
# ...
# Collect item detail item_id: 1463
# ...
# Collect item detail item_id: 1462
# ...
# Collect item detail item_id: 1461
# ...
# Collect item detail item_id: 1460
# ...
# Collect item detail item_id: 1457
# ...
# Collect item detail item_id: 1456
# ...
# Collect item detail item_id: 1454
# ...
# Collect item detail item_id: 1450
# ...
# Collect item detail item_id: 1444
# ...
# Collect item detail item_id: 1438
# ...
# Collect item detail item_id: 1436
# ...
# Collect item detail item_id: 1434
# ...
# Collect item detail item_id: 1428
# ...
# Collect item detail item_id: 1425
# ...
# Collect item detail item_id: 1424
# ...
# Collect item detail item_id: 1423
# ...
# Collect item detail item_id: 1422
# ...
# Collect item detail item_id: 1420
# ...
# Collect item detail item_id: 1418
# ...
# Collect item detail item_id: 1417
# ...
# Collect item detail item_id: 1415
# ...
# Collect item detail item_id: 1414
# ...
# Collect item detail item_id: 1413
# ...
# Collect item detail item_id: 1412
# ...
# Collect item detail item_id: 1411
# ...
# Collect item detail item_id: 1409
# ...
# Collect item detail item_id: 1403
# ...
# Collect item detail item_id: 1401
# ...
# Collect item detail item_id: 1399
# ...
# Collect item detail item_id: 1398
# ...
# Collect item detail item_id: 1388
# ...
# Collect item detail item_id: 1395
# ...
# Collect item detail item_id: 1394
# ...
# Collect item detail item_id: 1392
# ...
# Collect item detail item_id: 1389
# ...
# Collect item detail item_id: 1387
# ...
# Collect item detail item_id: 1386
# ...
# Collect item detail item_id: 1384
# ...
# Collect item detail item_id: 1382
# ...
# Collect item detail item_id: 1381
# ...
# Collect item detail item_id: 1378
# ...
# Collect item detail item_id: 1377
# ...
# Collect item detail item_id: 1372
# ...
# Collect item detail item_id: 1369
# ...
# Collect item detail item_id: 1367
# ...
# Collect item detail item_id: 1364
# ...
# Collect item detail item_id: 1363
# ...
# Collect item detail item_id: 1362
# ...
# Collect item detail item_id: 1357
# ...
# Collect item detail item_id: 1351
# ...
# Collect item detail item_id: 1348
# ...
# Collect item detail item_id: 1345
# ...
# Collect item detail item_id: 1344
# ...
# Collect item detail item_id: 1343
# ...
# Collect item detail item_id: 1334
# ...
# Collect item detail item_id: 1328
# ...
# Collect item detail item_id: 1333
# ...
# Collect item detail item_id: 1330
# ...
# Collect item detail item_id: 1325
# ...
# Collect item detail item_id: 1324
# ...
# Collect item detail item_id: 1323
# ...
# Collect item detail item_id: 1322
# ...
# Collect item detail item_id: 1321
# ...
# Collect item detail item_id: 1309
# ...
# Collect item detail item_id: 1305
# ...
# Collect item detail item_id: 1302
# ...
# Collect item detail item_id: 1299
# ...
# Collect item detail item_id: 1297
# ...
# Collect item detail item_id: 1295
# ...
# Collect item detail item_id: 1292
# ...
# Collect item detail item_id: 1286
# ...
# Collect item detail item_id: 1284
# ...
# Collect item detail item_id: 1283
# ...
# Collect item detail item_id: 1275
# ...
# Collect item detail item_id: 1271
# ...
# Collect item detail item_id: 1269
# ...
# Collect item detail item_id: 1264
# ...
# Collect item detail item_id: 1263
# ...
# Collect item detail item_id: 1260
# ...
# Collect item detail item_id: 1256
# ...
# Collect item detail item_id: 1246
# ...
# Collect item detail item_id: 1244
# ...
# Collect item detail item_id: 1240
# ...
# Collect item detail item_id: 1237
# ...
# Collect item detail item_id: 1234
# ...
# Collect item detail item_id: 1228
# ...
# Collect item detail item_id: 1220
# ...
# Collect item detail item_id: 1217
# ...
# Collect item detail item_id: 1215
# ...
# Collect item detail item_id: 1212
# ...
# Collect item detail item_id: 1207
# ...
# Collect item detail item_id: 1204
# ...
# Collect item detail item_id: 1203
# ...
# Collect item detail item_id: 1202
# ...
# Collect item detail item_id: 1198
# ...
# Collect item detail item_id: 1193
# ...
# Collect item detail item_id: 1190
# ...
# Collect item detail item_id: 1187
# ...
# Collect item detail item_id: 1183
# ...
# Collect item detail item_id: 1180
# ...
# Collect item detail item_id: 1179
# ...
# Collect item detail item_id: 1178
# ...
# Collect item detail item_id: 1172
# ...
# Collect item detail item_id: 1158
# ...
# Collect item detail item_id: 1156
# ...
# Collect item detail item_id: 1147
# ...
# Collect item detail item_id: 1145
# ...
# Collect item detail item_id: 1144
# ...
# Collect item detail item_id: 1139
# ...
# Collect item detail item_id: 1132
# ...
# Collect item detail item_id: 1126
# ...
# Collect item detail item_id: 1123
# ...
# Collect item detail item_id: 1122
# ...
# Collect item detail item_id: 1121
# ...
# Collect item detail item_id: 1120
# ...
# Collect item detail item_id: 1117
# ...
# Collect item detail item_id: 1115
# ...
# Collect item detail item_id: 1114
# ...
# Collect item detail item_id: 1111
# ...
# Collect item detail item_id: 1109
# ...
# Collect item detail item_id: 1108
# ...
# Collect item detail item_id: 1107
# ...
# Collect item detail item_id: 1106
# ...
# Collect item detail item_id: 1105
# ...
# Collect item detail item_id: 1103
# ...
# Collect item detail item_id: 1102
# ...
# Collect item detail item_id: 1100
# ...
# Collect item detail item_id: 1099
# ...
# Collect item detail item_id: 1098
# ...
# Collect item detail item_id: 1094
# ...
# Collect item detail item_id: 1093
# ...
# Collect item detail item_id: 1089
# ...
# Collect item detail item_id: 1088
# ...
# Collect item detail item_id: 1086
# ...
# Collect item detail item_id: 1084
# ...
# Collect item detail item_id: 1083
# ...
# Collect item detail item_id: 1080
# ...
# Collect item detail item_id: 1079
# ...
# Collect item detail item_id: 1074
# ...
# Collect item detail item_id: 1072
# ...
# Collect item detail item_id: 1070
# ...
# Collect item detail item_id: 1069
# ...
# Collect item detail item_id: 1068
# ...
# Collect item detail item_id: 1065
# ...
# Collect item detail item_id: 1063
# ...
# Collect item detail item_id: 1061
# ...
# Collect item detail item_id: 1059
# ...
# Collect item detail item_id: 1055
# ...
# Collect item detail item_id: 1050
# ...
# Collect item detail item_id: 1048
# ...
# Collect item detail item_id: 1046
# ...
# Collect item detail item_id: 1044
# ...
# Collect item detail item_id: 1043
# ...
# Collect item detail item_id: 1040
# ...
# Collect item detail item_id: 1039
# ...
# Collect item detail item_id: 1036
# ...
# Collect item detail item_id: 1035
# ...
# Collect item detail item_id: 1034
# ...
# Collect item detail item_id: 1032
# ...
# Collect item detail item_id: 1029
# ...
# Collect item detail item_id: 1026
# ...
# Collect item detail item_id: 1023
# ...
# Collect item detail item_id: 1020
# ...
# Collect item detail item_id: 1018
# ...
# Collect item detail item_id: 1016
# ...
# Collect item detail item_id: 1014
# ...
# Collect item detail item_id: 1011
# ...
# Collect item detail item_id: 1007
# ...
# Collect item detail item_id: 1006
# ...
# Collect item detail item_id: 1005
# ...
# Collect item detail item_id: 1002
# ...
# Collect item detail item_id: 998
# ...
# Collect item detail item_id: 997
# ...
# Collect item detail item_id: 996
# ...
# Collect item detail item_id: 995
# ...
# Collect item detail item_id: 994
# ...
# Collect item detail item_id: 993
# ...
# Collect item detail item_id: 992
# ...
# Collect item detail item_id: 988
# ...
# Collect item detail item_id: 987
# ...
# Collect item detail item_id: 983
# ...
# Collect item detail item_id: 974
# ...
# Collect item detail item_id: 969
# ...
# Collect item detail item_id: 967
# ...
# Collect item detail item_id: 964
# ...
# Collect item detail item_id: 960
# ...
# Collect item detail item_id: 957
# ...
# Collect item detail item_id: 952
# ...
# Collect item detail item_id: 951
# ...
# Collect item detail item_id: 950
# ...
# Collect item detail item_id: 946
# ...
# Collect item detail item_id: 945
# ...
# Collect item detail item_id: 942
# ...
# Collect item detail item_id: 940
# ...
# Collect item detail item_id: 939
# ...
# Collect item detail item_id: 933
# ...
# Collect item detail item_id: 932
# ...
# Collect item detail item_id: 929
# ...
# Collect item detail item_id: 925
# ...
# Collect item detail item_id: 922
# ...
# Collect item detail item_id: 913
# ...
# Collect item detail item_id: 912
# ...
# Collect item detail item_id: 906
# ...
# Collect item detail item_id: 905
# ...
# Collect item detail item_id: 903
# ...
# Collect item detail item_id: 902
# ...
# Collect item detail item_id: 895
# ...
# Collect item detail item_id: 893
# ...
# Collect item detail item_id: 892
# ...
# Collect item detail item_id: 891
# ...
# Collect item detail item_id: 889
# ...
# Collect item detail item_id: 887
# ...
# Collect item detail item_id: 885
# ...
# Collect item detail item_id: 880
# ...
# Collect item detail item_id: 878
# ...
# Collect item detail item_id: 877
# ...
# Collect item detail item_id: 874
# ...
# Collect item detail item_id: 870
# ...
# Collect item detail item_id: 869
# ...
# Collect item detail item_id: 865
# ...
# Collect item detail item_id: 857
# ...
# Collect item detail item_id: 855
# ...
# Collect item detail item_id: 851
# ...
# Collect item detail item_id: 850
# ...
# Collect item detail item_id: 849
# ...
# Collect item detail item_id: 847
# ...
# Collect item detail item_id: 846
# ...
# Collect item detail item_id: 842
# ...
# Collect item detail item_id: 841
# ...
# Collect item detail item_id: 834
# ...
# Collect item detail item_id: 833
# ...
# Collect item detail item_id: 831
# ...
# Collect item detail item_id: 826
# ...
# Collect item detail item_id: 822
# ...
# Collect item detail item_id: 818
# ...
# Collect item detail item_id: 817
# ...
# Collect item detail item_id: 811
# ...
# Collect item detail item_id: 808
# ...
# Collect item detail item_id: 807
# ...
# Collect item detail item_id: 806
# ...
# Collect item detail item_id: 802
# ...
# Collect item detail item_id: 797
# ...
# Collect item detail item_id: 795
# ...
# Collect item detail item_id: 794
# ...
# Collect item detail item_id: 793
# ...
# Collect item detail item_id: 791
# ...
# Collect item detail item_id: 790
# ...
# Collect item detail item_id: 786
# ...
# Collect item detail item_id: 782
# ...
# Collect item detail item_id: 781
# ...
# Collect item detail item_id: 778
# ...
# Collect item detail item_id: 777
# ...
# Collect item detail item_id: 775
# ...
# Collect item detail item_id: 774
# ...
# Collect item detail item_id: 773
# ...
# Collect item detail item_id: 770
# ...
# Collect item detail item_id: 765
# ...
# Collect item detail item_id: 762
# ...
# Collect item detail item_id: 760
# ...
# Collect item detail item_id: 759
# ...
# Collect item detail item_id: 755
# ...
# Collect item detail item_id: 754
# ...
# Collect item detail item_id: 752
# ...
# Collect item detail item_id: 751
# ...
# Collect item detail item_id: 749
# ...
# Collect item detail item_id: 747
# ...
# Collect item detail item_id: 744
# ...
# Collect item detail item_id: 743
# ...
# Collect item detail item_id: 741
# ...
# Collect item detail item_id: 740
# ...
# Collect item detail item_id: 738
# ...
# Collect item detail item_id: 737
# ...
# Collect item detail item_id: 736
# ...
# Collect item detail item_id: 730
# ...
# Collect item detail item_id: 727
# ...
# Collect item detail item_id: 724
# ...
# Collect item detail item_id: 723
# ...
# Collect item detail item_id: 722
# ...
# Collect item detail item_id: 719
# ...
# Collect item detail item_id: 717
# ...
# Collect item detail item_id: 716
# ...
# Collect item detail item_id: 715
# ...
# Collect item detail item_id: 713
# ...
# Collect item detail item_id: 711
# ...
# Collect item detail item_id: 709
# ...
# Collect item detail item_id: 707
# ...
# Collect item detail item_id: 706
# ...
# Collect item detail item_id: 700
# ...
# Collect item detail item_id: 695
# ...
# Collect item detail item_id: 692
# ...
# Collect item detail item_id: 688
# ...
# Collect item detail item_id: 686
# ...
# Collect item detail item_id: 677
# ...
# Collect item detail item_id: 673
# ...
# Collect item detail item_id: 671
# ...
# Collect item detail item_id: 670
# ...
# Collect item detail item_id: 666
# ...
# Collect item detail item_id: 664
# ...
# Collect item detail item_id: 653
# ...
# Collect item detail item_id: 651
# ...
# Collect item detail item_id: 649
# ...
# Collect item detail item_id: 647
# ...
# Collect item detail item_id: 645
# ...
# Collect item detail item_id: 640
# ...
# Collect item detail item_id: 639
# ...
# Collect item detail item_id: 638
# ...
# Collect item detail item_id: 635
# ...
# Collect item detail item_id: 632
# ...
# Collect item detail item_id: 630
# ...
# Collect item detail item_id: 628
# ...
# Collect item detail item_id: 625
# ...
# Collect item detail item_id: 617
# ...
# Collect item detail item_id: 612
# ...
# Collect item detail item_id: 608
# ...
# Collect item detail item_id: 605
# ...
# Collect item detail item_id: 602
# ...
# Collect item detail item_id: 598
# ...
# Collect item detail item_id: 597
# ...
# Collect item detail item_id: 595
# ...
# Collect item detail item_id: 592
# ...
# Collect item detail item_id: 589
# ...
# Collect item detail item_id: 586
# ...
# Collect item detail item_id: 583
# ...
# Collect item detail item_id: 577
# ...
# Collect item detail item_id: 574
# ...
# Collect item detail item_id: 567
# ...
# Collect item detail item_id: 566
# ...
# Collect item detail item_id: 560
# ...
# Collect item detail item_id: 557
# ...
# Collect item detail item_id: 555
# ...
# Collect item detail item_id: 554
# ...
# Collect item detail item_id: 552
# ...
# Collect item detail item_id: 544
# ...
# Collect item detail item_id: 540
# ...
# Collect item detail item_id: 535
# ...
# Collect item detail item_id: 532
# ...
# Collect item detail item_id: 531
# ...
# Collect item detail item_id: 528
# ...
# Collect item detail item_id: 527
# ...
# Collect item detail item_id: 526
# ...
# Collect item detail item_id: 523
# ...
# Collect item detail item_id: 522
# ...
# Collect item detail item_id: 520
# ...
# Collect item detail item_id: 517
# ...
# Collect item detail item_id: 514
# ...
# Collect item detail item_id: 512
# ...
# Collect item detail item_id: 509
# ...
# Collect item detail item_id: 507
# ...
# Collect item detail item_id: 505
# ...
# Collect item detail item_id: 502
# ...
# Collect item detail item_id: 499
# ...
# Collect item detail item_id: 495
# ...
# Collect item detail item_id: 493
# ...
# Collect item detail item_id: 483
# ...
# Collect item detail item_id: 482
# ...
# Collect item detail item_id: 471
# ...
# Collect item detail item_id: 468
# ...
# Collect item detail item_id: 465
# ...
# Collect item detail item_id: 453
# ...
# Collect item detail item_id: 449
# ...
# Collect item detail item_id: 442
# ...
# Collect item detail item_id: 439
# ...
# Collect item detail item_id: 434
# ...
# Collect item detail item_id: 432
# ...
# Collect item detail item_id: 318
# ...

# %%
print('Total product count:', len(house_warming_item_detail_crawler.house_warming_details))
print(house_warming_item_detail_crawler.house_warming_details[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-03256ea11b46> in <module>
# ----> 1 print('Total product count:', len(house_warming_item_detail_crawler.house_warming_details))
#       2 print(house_warming_item_detail_crawler.house_warming_details[0])
#
# NameError: name 'house_warming_item_detail_crawler' is not defined

# %% [markdown]
# # `input/data-house-warming.csv` 생성

# %%
import os
import shutil

input_dir_path = os.path.join(os.getcwd(), 'input')
if os.path.exists(input_dir_path) is False:
    # 현재 위치에 input 폴더 생성
    os.mkdir(input_dir_path)

# %%
# input 폴더 만들고 data.csv 에 product_n_reviews 내용 저장하기
import pandas

df = pandas.DataFrame(house_warming_item_detail_crawler.house_warming_details)
df.head(3)
# Out:
#       id residence area region expertise color_list style_list  \
# 0  40578       아파트  30평    경기도     홈스타일링
# 1  39868       아파트  33평  울산광역시      리모델링    화이트,그레이     미니멀&심플
# 2  39270   원룸&오피스텔   8평    경기도     홈스타일링                미니멀&심플
#
#        constructions                              purchased_product_ids  \
# 0                     [10865, 36591, 36592, 81695, 154085, 163351, 1...
# 1  주방리모델링,조명시공,발코니확장  [61601, 68072, 97064, 108193, 153647, 194353, ...
# 2                     [57577, 69119, 71718, 144799, 209658, 215597, ...
#
#       family_list  like_count  reply_count  scrap_count  view_count  \
# 0  [부모님과 함께 사는 집]          14            2          184        6311
# 1          [신혼부부]         450           42          902       40882
# 2         [싱글라이프]          82           23          293        8092
#
#    share_count
# 0            0
# 1          211
# 2           14

# %%
df.to_csv("./input/data-house-warming.csv", sep='\t', na_rep='', encoding="UTF-16")

# %%
# 잘 만들어졌는지 확인
pandas.read_csv('./input/data-house-warming.csv', sep='\t', encoding="UTF-16")
# Out:
#       Unnamed: 0     id residence  area     region expertise      color_list  \
# 0              0  40578       아파트   30평        경기도     홈스타일링             NaN
# 1              1  39868       아파트   33평      울산광역시      리모델링         화이트,그레이
# 2              2  39270   원룸&오피스텔    8평        경기도     홈스타일링             NaN
# 3              3  39218      단독주택   15평  서울특별시 종로구     홈스타일링             브라운
# 4              4  38991       아파트   30평      부산광역시     홈스타일링     그레이,베이지,브라운
# ...          ...    ...       ...   ...        ...       ...             ...
# 4150        4150    442       아파트  20평대        NaN     홈스타일링             브라운
# 4151        4151    439       아파트  20평대        NaN      리모델링         화이트,그레이
# 4152        4152    434       아파트   24평        NaN     홈스타일링             브라운
# 4153        4153    432       아파트  20평대        NaN     홈스타일링      라이트 브라운,블루
# 4154        4154    318   원룸&오피스텔   10평      서울특별시     홈스타일링  화이트,라이트 브라운,레드
#
#              style_list      constructions  \
# 0                   NaN                NaN
# 1                미니멀&심플  주방리모델링,조명시공,발코니확장
# 2                미니멀&심플                NaN
# 3            미니멀&심플,내추럴                NaN
# 4     모던,미니멀&심플,내추럴,북유럽            조명시공,중문
# ...                 ...                ...
# 4150                내추럴                NaN
# 4151                내추럴                NaN
# 4152                내추럴                NaN
# 4153                내추럴      조명시공,중문,발코니확장
# 4154           유니크&믹스매치                NaN
#
#                                   purchased_product_ids       family_list  \
# 0     [10865, 36591, 36592, 81695, 154085, 163351, 1...  ['부모님과 함께 사는 집']
# 1     [61601, 68072, 97064, 108193, 153647, 194353, ...          ['신혼부부']
# 2     [57577, 69119, 71718, 144799, 209658, 215597, ...         ['싱글라이프']
# 3     [611, 25202, 32236, 45201, 89696, 119201, 1657...          ['신혼부부']
# 4     [6752, 34365, 38044, 40513, 42263, 71714, 8525...          ['신혼부부']
# ...                                                 ...               ...
# 4150  [68, 69, 70, 71, 72, 73, 74, 75, 416, 14749, 3...          ['신혼부부']
# 4151  [56, 57, 58, 59, 61, 66, 313, 409, 410, 411, 4...          ['신혼부부']
# 4152            [1, 4, 5, 6, 472, 484, 488, 494, 81927]      ['아기가 있는 집']
# 4153  [8, 9, 10, 15, 16, 17, 18, 19, 20, 22, 49, 100...          ['신혼부부']
# 4154  [55, 1490, 2254, 2255, 2256, 2257, 2258, 2259,...         ['싱글라이프']
#
#       like_count  reply_count  scrap_count  view_count  share_count
# 0             14            2          184        6311            0
# 1            450           42          902       40882          211
# 2             82           23          293        8092           14
# 3             51            8          125        6124           12
# 4            149           16          586       13621           43
# ...          ...          ...          ...         ...          ...
# 4150          65           10          244       31543           37
# 4151          79           17          320       41496           50
# 4152          26            6           65       14829           20
# 4153          41            8           60       15149           17
# 4154         235           18          295       42778          110
#
# [4155 rows x 16 columns]
