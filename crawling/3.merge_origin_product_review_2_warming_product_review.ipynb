# %%
import pandas as pd
import os
import numpy as np

df = pd.read_csv('./input/data-house-warming.csv', sep='\t', encoding="UTF-16")

# %%
purchased_product_ids_per_row = df['purchased_product_ids'].values

# %%
house_warming_product_ids = set()
for purchased_product_ids in purchased_product_ids_per_row:
    items = purchased_product_ids.replace('[', '').replace(']', '').split(', ')
    house_warming_product_ids.update(items)
house_warming_product_ids.remove('')

# %%
house_warming_product_ids
# Out:
# {'106711',
#  '45092',
#  '38184',
#  '75809',
#  '33549',
#  '282241',
#  '13524',
#  '169650',
#  '342848',
#  '157582',
#  '152642',
#  '104344',
#  '83659',
#  '1411',
#  '200461',
#  '173388',
#  '24473',
#  '3934',
#  '132914',
#  '370536',
#  '145716',
#  '71304',
#  '228',
#  '421952',
#  '158128',
#  '28655',
#  '319878',
#  '543116',
#  '309408',
#  '15334',
#  '405167',
#  '169446',
#  '89741',
#  '15856',
#  '86685',
#  '61367',
#  '74573',
#  '468121',
#  '81777',
#  '175122',
#  '277486',
#  '150145',
#  '434',
#  '602897',
#  '203517',
#  '471603',
#  '239060',
#  '453666',
#  '262358',
#  '232886',
#  '126962',
#  '32133',
#  '36267',
#  '102289',
#  '13912',
#  '289321',
#  '406385',
#  '502409',
#  '170784',
#  '29653',
#  '57888',
#  '37881',
#  '241101',
#  '129579',
#  '149548',
#  '77918',
#  '436127',
#  '238345',
#  '68916',
#  '36719',
#  '36448',
#  '3940',
#  '308620',
#  '1970',
#  '270153',
#  '4484',
#  '13897',
#  '206840',
#  '40109',
#  '2440',
#  '1784',
#  '111698',
#  '410200',
#  '154299',
#  '86426',
#  '81831',
#  '31445',
#  '52734',
#  '148329',
#  '152645',
#  '252',
#  '104745',
#  '577398',
#  '153852',
#  '104351',
#  '340164',
#  '448968',
#  '452471',
#  '80947',
#  '280218',
#  '510512',
#  '22869',
#  '381431',
#  '57744',
#  '488640',
#  '130618',
#  '338655',
#  '100034',
#  '186909',
#  '97032',
#  '360605',
#  '3271',
#  '86728',
#  '609462',
#  '158783',
#  '107500',
#  '222858',
#  '265827',
#  '100845',
#  '104144',
#  '72899',
#  '3521',
#  '6120',
#  '113889',
#  '292527',
#  '244642',
#  '201980',
#  '238515',
#  '150633',
#  '123591',
#  '162907',
#  '381053',
#  '42617',
#  '182818',
#  '101026',
#  '235948',
#  '244858',
#  '244718',
#  '104219',
#  '49866',
#  '503036',
#  '251078',
#  '125808',
#  '221533',
#  '524524',
#  '526480',
#  '191860',
#  '3212',
#  '23275',
#  '253632',
#  '24669',
#  '210787',
#  '487487',
#  '2378',
#  '78983',
#  '161469',
#  '176477',
#  '111707',
#  '52105',
#  '236801',
#  '260660',
#  '33655',
#  '36207',
#  '279487',
#  '19901',
#  '1853',
#  '221185',
#  '374140',
#  '39915',
#  '110274',
#  '494687',
#  '277009',
#  '215103',
#  '292808',
#  '9709',
#  '505191',
#  '277336',
#  '10600',
#  '25615',
#  '420850',
#  '70737',
#  '230797',
#  '134254',
#  '159564',
#  '270922',
#  '32248',
#  '161149',
#  '11701',
#  '58447',
#  '238180',
#  '132761',
#  '6472',
#  '1049',
#  '160069',
#  '375459',
#  '147962',
#  '19793',
#  '371997',
#  '86120',
#  '5279',
#  '469804',
#  '36164',
#  '256589',
#  '66931',
#  '10',
#  '19556',
#  '114436',
#  '149821',
#  '499032',
#  '529491',
#  '52961',
#  '138970',
#  '274701',
#  '228999',
#  '137873',
#  '118103',
#  '107451',
#  '5767',
#  '145165',
#  '153728',
#  '201612',
#  '17005',
#  '322534',
#  '80188',
#  '50784',
#  '164681',
#  '393947',
#  '182931',
#  '50442',
#  '215851',
#  '38495',
#  '242489',
#  '189560',
#  '55136',
#  '8241',
#  '55710',
#  '160781',
#  '25590',
#  '376230',
#  '57788',
#  '411962',
#  '97796',
#  '76650',
#  '332870',
#  '9998',
#  '251101',
#  '153118',
#  '265505',
#  '158872',
#  '15422',
#  '264792',
#  '6346',
#  '327761',
#  '75670',
#  '9673',
#  '173655',
#  '1712',
#  '280197',
#  '157560',
#  '207045',
#  '65825',
#  '45875',
#  '390559',
#  '207249',
#  '73409',
#  '50938',
#  '71314',
#  '86756',
#  '375093',
#  '6453',
#  '386020',
#  '72339',
#  '717',
#  '212777',
#  '26796',
#  '39777',
#  '72552',
#  '254303',
#  '87225',
#  '97651',
#  '17520',
#  '68817',
#  '163876',
#  '31841',
#  '88245',
#  '214555',
#  '13169',
#  '3224',
#  '352418',
#  '6956',
#  '337329',
#  '83405',
#  '234465',
#  '89548',
#  '7249',
#  '111240',
#  '61396',
#  '162948',
#  '257334',
#  '85259',
#  '401297',
#  '299330',
#  '44303',
#  '129839',
#  '141275',
#  '183211',
#  '6620',
#  '161345',
#  '167117',
#  '369381',
#  '269822',
#  '73147',
#  '36080',
#  '278926',
#  '312739',
#  '24506',
#  '153237',
#  '120091',
#  '355549',
#  '469693',
#  '249499',
#  '106373',
#  '45815',
#  '150960',
#  '222130',
#  '355678',
#  '184509',
#  '302226',
#  '171186',
#  '82106',
#  '195764',
#  '95363',
#  '28375',
#  '385925',
#  '37204',
#  '556782',
#  '440336',
#  '36591',
#  '45765',
#  '104650',
#  '253076',
#  '108226',
#  '97775',
#  '66134',
#  '89603',
#  '160743',
#  '161832',
#  '311859',
#  '38692',
#  '146857',
#  '420142',
#  '537316',
#  '3736',
#  '419194',
#  '103549',
#  '78479',
#  '171762',
#  '7613',
#  '238298',
#  '74859',
#  '83004',
#  '38797',
#  '261911',
#  '87296',
#  '279384',
#  '59910',
#  '295651',
#  '940',
#  '383349',
#  '310825',
#  '13158',
#  '323435',
#  '33516',
#  '310252',
#  '291410',
#  '4293',
#  '419178',
#  '53579',
#  '120625',
#  '1666',
#  '438875',
#  '406924',
#  '112112',
#  '10920',
#  '201124',
#  '225500',
#  '174222',
#  '102184',
#  '106313',
#  '52766',
#  '81004',
#  '182495',
#  '352614',
#  '195734',
#  '134538',
#  '39858',
#  '125106',
#  '29356',
#  '244936',
#  '311493',
#  '295435',
#  '282981',
#  '54154',
#  '239092',
#  '74906',
#  '2334',
#  '32134',
#  '263529',
#  '23841',
#  '575280',
#  '38912',
#  '114006',
#  '206116',
#  '293509',
#  '564438',
#  '40387',
#  '255646',
#  '250592',
#  '51994',
#  '7390',
#  '287342',
#  '219430',
#  '25573',
#  '260674',
#  '157525',
#  '343745',
#  '182860',
#  '154293',
#  '206834',
#  '179610',
#  '201786',
#  '68536',
#  '227394',
#  '31820',
#  '4980',
#  '295433',
#  '88170',
#  '41207',
#  '154515',
#  '82081',
#  '296652',
#  '312751',
#  '274823',
#  '189152',
#  '8543',
#  '405619',
#  '88683',
#  '72328',
#  '163242',
#  '157868',
#  '172940',
#  '277681',
#  '97519',
#  '36293',
#  '149820',
#  '79569',
#  '425387',
#  '121132',
#  '431742',
#  '189143',
#  '226853',
#  '61602',
#  '409',
#  '240540',
#  '488187',
#  '179776',
#  '42613',
#  '23529',
#  '28531',
#  '3167',
#  '106712',
#  '99367',
#  '298986',
#  '169351',
#  '228948',
#  '316479',
#  '43323',
#  '195094',
#  '45203',
#  '29308',
#  '465583',
#  '108202',
#  '458609',
#  '5556',
#  '33134',
#  '138112',
#  '22408',
#  '32345',
#  '125825',
#  '306945',
#  '12413',
#  '298838',
#  '381692',
#  '104698',
#  '101133',
#  '151900',
#  '355584',
#  '207847',
#  '367017',
#  '153331',
#  '484657',
#  '202511',
#  '148038',
#  '90607',
#  '347764',
#  '11651',
#  '30354',
#  '29463',
#  '57370',
#  '501816',
#  '245795',
#  '477250',
#  '53161',
#  '157297',
#  '251270',
#  '54301',
#  '178149',
#  '10188',
#  '6560',
#  '15018',
#  '155210',
#  '28498',
#  '184427',
#  '551006',
#  '30529',
#  '453684',
#  '87808',
#  '226299',
#  '36670',
#  '229082',
#  '8922',
#  '42302',
#  '124028',
#  '171071',
#  '14329',
#  '384743',
#  '3369',
#  '358063',
#  '224642',
#  '164932',
#  '450712',
#  '41244',
#  '108159',
#  '198744',
#  '428840',
#  '32329',
#  '284152',
#  '327978',
#  '182798',
#  '266686',
#  '99206',
#  '365387',
#  '45464',
#  '276232',
#  '144355',
#  '3104',
#  '30303',
#  '279421',
#  '151903',
#  '488264',
#  '180576',
#  '104137',
#  '332873',
#  '9488',
#  '320111',
#  '292528',
#  '262376',
#  '170346',
#  '352301',
#  '50731',
#  '60484',
#  '10453',
#  '28600',
#  '31065',
#  '405928',
#  '171839',
#  '178471',
#  '77223',
#  '79327',
#  '306358',
#  '397478',
#  '44776',
#  '89299',
#  '253049',
#  '99304',
#  '43386',
#  '229650',
#  '605719',
#  '187751',
#  '114435',
#  '194065',
#  '65710',
#  '407961',
#  '94778',
#  '215462',
#  '529705',
#  '235284',
#  '182016',
#  '255419',
#  '314450',
#  '89256',
#  '102308',
#  '6121',
#  '15131',
#  '70720',
#  '6289',
#  '235427',
#  '399315',
#  '131321',
#  '415154',
#  '210351',
#  '47119',
#  '81608',
#  '538380',
#  '164593',
#  '158266',
#  '45525',
#  '38591',
#  '327461',
#  '134682',
#  '79390',
#  '4831',
#  '100843',
#  '162626',
#  '16405',
#  '140342',
#  '270494',
#  '34031',
#  '409325',
#  '5048',
#  '357',
#  '18379',
#  '8699',
#  '284378',
#  '229063',
#  '23672',
#  '449819',
#  '6074',
#  '330815',
#  '19768',
#  '433203',
#  '279402',
#  '50927',
#  '1282',
#  '153703',
#  '65047',
#  '447701',
#  '7466',
#  '217365',
#  '159887',
#  '36580',
#  '10554',
#  '385341',
#  '239475',
#  '311942',
#  '499111',
#  '345156',
#  '48607',
#  '24018',
#  '3475',
#  '1745',
#  '549826',
#  '99687',
#  '33874',
#  '3634',
#  '190644',
#  '78688',
#  '73530',
#  '201112',
#  '445445',
#  '8136',
#  '288706',
#  '77623',
#  '58907',
#  '257820',
#  '249271',
#  '108135',
#  '101168',
#  '223941',
#  '250932',
#  '176632',
#  '264469',
#  '264620',
#  '60118',
#  '150564',
#  '152371',
#  '111274',
#  '70641',
#  '227938',
#  '580721',
#  '107525',
#  '57248',
#  '87542',
#  '374476',
#  '2832',
#  '81698',
#  '42769',
#  '7606',
#  '239173',
#  '152636',
#  '251459',
#  '71221',
#  '244648',
#  '369018',
#  '7835',
#  '406318',
#  '138318',
#  '35827',
#  '158048',
#  '80314',
#  '167562',
#  '298826',
#  '138322',
#  '6712',
#  '30244',
#  '222864',
#  '117752',
#  '293920',
#  '43304',
#  '151193',
#  '355727',
#  '451543',
#  '167635',
#  '530478',
#  '152436',
#  '132166',
#  '33493',
#  '5824',
#  '18436',
#  '205631',
#  '208837',
#  '11993',
#  '594375',
#  '36686',
#  '110204',
#  '536738',
#  '153897',
#  '32224',
#  '359125',
#  '229657',
#  '338351',
#  '182836',
#  '28208',
#  '102204',
#  '280532',
#  '190061',
#  '502541',
#  '72850',
#  '300543',
#  '530668',
#  '158980',
#  '307047',
#  '7450',
#  '134160',
#  '588367',
#  '127170',
#  '91713',
#  '6387',
#  '112161',
#  '24200',
#  '468460',
#  '572581',
#  '141162',
#  '254085',
#  '135411',
#  '237247',
#  '315959',
#  '445626',
#  '150913',
#  '81049',
#  '46243',
#  '15126',
#  '45194',
#  '86221',
#  '538569',
#  '388330',
#  '209328',
#  '388715',
#  '41130',
#  '194560',
#  '36948',
#  '46124',
#  '418652',
#  '83787',
#  '30631',
#  '549866',
#  '88574',
#  '5381',
#  '365211',
#  '137749',
#  '464410',
#  '150407',
#  '190962',
#  '2583',
#  '309399',
#  '75169',
#  '361641',
#  '396302',
#  '189802',
#  '56122',
#  '220490',
#  '96890',
#  '34536',
#  '2521',
#  '422328',
#  '251430',
#  '107457',
#  '69161',
#  '231533',
#  '27051',
#  '284914',
#  '219447',
#  '187689',
#  '35586',
#  '82409',
#  '2249',
#  '198738',
#  '4262',
#  '75109',
#  '85814',
#  '255944',
#  '199254',
#  '258457',
#  '506400',
#  '141236',
#  '105348',
#  '24971',
#  '66103',
#  '106058',
#  '89851',
#  '241077',
#  '178735',
#  '3864',
#  '159359',
#  '95376',
#  '72452',
#  '309605',
#  '187741',
#  '113569',
#  '190806',
#  '173520',
#  '468897',
#  '36718',
#  '379927',
#  '71348',
#  '157634',
#  '334282',
#  '296856',
#  '246803',
#  '3863',
#  '95161',
#  '310631',
#  '322506',
#  '173453',
#  '161497',
#  '15193',
#  '60425',
#  '72113',
#  '57588',
#  '115805',
#  '235292',
#  '74969',
#  '135387',
#  '256874',
#  '32824',
#  '39216',
#  '199417',
#  '126043',
#  '384228',
#  '23785',
#  '115899',
#  '73428',
#  '25200',
#  '381641',
#  '96084',
#  '3256',
#  '218684',
#  '679',
#  '120983',
#  '66066',
#  '161457',
#  '226798',
#  '118928',
#  '465572',
#  '85340',
#  '11114',
#  '22649',
#  '447358',
#  '149381',
#  '83128',
#  '169164',
#  '157628',
#  '97961',
#  '453966',
#  '207736',
#  '344747',
#  '122639',
#  '135849',
#  '292592',
#  '180259',
#  '135721',
#  '117830',
#  '108582',
#  '224579',
#  '968',
#  '283287',
#  '18438',
#  '6615',
#  '224663',
#  '24379',
#  '2109',
#  '43472',
#  '150837',
#  '152882',
#  '157350',
#  '196904',
#  '136887',
#  '37639',
#  '36579',
#  '145314',
#  '74755',
#  '453023',
#  '8281',
#  '157524',
#  '3807',
#  '134692',
#  '232309',
#  '318870',
#  '87357',
#  '296262',
#  '239893',
#  '212634',
#  '6269',
#  '82',
#  '223010',
#  '277007',
#  '9232',
#  '11170',
#  '280956',
#  '474219',
#  '103215',
#  '288348',
#  '514019',
#  '201824',
#  '78760',
#  '479587',
#  '16134',
#  '183572',
#  '170581',
#  '158640',
#  '289664',
#  '46797',
#  '1609',
#  '55105',
#  '106625',
#  '37467',
#  '271357',
#  '41664',
#  '32173',
#  '225770',
#  '230218',
#  '198587',
#  '55308',
#  '253339',
#  '54238',
#  '9004',
#  '286301',
#  '476803',
#  '118886',
#  '110412',
#  '298706',
#  '177236',
#  '483686',
#  '158742',
#  '420180',
#  '200294',
#  '199204',
#  '61141',
#  '225505',
#  '204693',
#  '244115',
#  '272810',
#  '333246',
#  '9260',
#  '83312',
#  '238202',
#  '182922',
#  '89222',
#  '1069',
#  '3011',
#  '4048',
#  '207141',
#  '72941',
#  '104661',
#  '190804',
#  '212877',
#  '251535',
#  '41967',
#  '81883',
#  '6115',
#  ...}

# %%
df.loc[df['purchased_product_ids'].isin(str(270153))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-3ef80da1d46a> in <module>
# ----> 1 df.loc[df['purchased_product_ids'].isin(str(270153))]
#
# d:\program\python\python37\lib\site-packages\pandas\core\series.py in isin(self, values)
#    4683         Name: animal, dtype: bool
#    4684         """
# -> 4685         result = algorithms.isin(self, values)
#    4686         return self._constructor(result, index=self.index).__finalize__(
#    4687             self, method="isin"
#
# d:\program\python\python37\lib\site-packages\pandas\core\algorithms.py in isin(comps, values)
#     416     if not is_list_like(values):
#     417         raise TypeError(
# --> 418             "only list-like objects are allowed to be passed "
#     419             f"to isin(), you passed a [{type(values).__name__}]"
#     420         )
#
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]

# %%
# 웹 사이트로부터 데이터를 얻어오는 클래스
import requests
import json

class Requester:
    def get_data(self, url, parameters = {}):
        if (url is None) or (url.strip() is ''):
            raise Exception('url should not be empty')
        
        response = requests.get(url.strip(), params = parameters)
        if response.status_code is not 200:
            print('[ERROER]Can not receive response')

        response_text = (response.text is None) and '{}' or response.text
        json_response = json.loads(response_text)
        return json_response

# %%
# https://ohou.se/productions/41655/selling.json
from time import sleep

class ProductCrawler:
    def __init__(self, house_warming_product_ids = [], house_warming_df = None):
        self.products = list()
        self.house_warming_product_ids = house_warming_product_ids
        self.requester = Requester()
        self.product_n_reviews = list()
        self.house_warming_df = house_warming_df
        self.default_page_size = 5000
    
    def get_product_detail(self, product_id):
        url = 'https://ohou.se/productions/'+ str(product_id) + '/selling.json'
        response = self.requester.get_data(url)
        return response
    
    def collect_production(self, production = {}):
        self.products.append({
            'id': production['id'],
            'name': production['name'],
            'review_count': production['review_count'], #  제품에 남겨진 리뷰 총 갯수
            'review_average': production['review_avg'],  # 제품에 남겨진 평점 평균
            'scrap_count': production['scrap_count'],  # 제품을 스크랩한 총 갯수
            'view_count': production['view_count'],  # 제품을 본 횟수
            #'review_text': '' # 이 부분은 아래 코드 블록에서 수행 예정
        })
        
    def calculat_total_page(self, total_item_count):
        if (total_item_count is None) or (total_item_count <= 0):
            return 1
        total_page = (total_item_count // self.default_page_size)
        if (total_item_count % self.default_page_size) is not 0:
            total_page = total_page + 1
        return total_page
    
    def get_production_review_data_by_page(self, product_id, page):
        parameters = {
             'order': 'best', # 고정 queryParam 값. 베스트 리뷰순으로 가져오기위한 정렬값
             'per': str(self.default_page_size), # 고정 queryParam 값. 페이에 출력될 아이템 갯수
             'production_id': str(product_id),
             'page': str(page)
        }
        url = 'https://ohou.se/production_reviews.json'
        response = self.requester.get_data(url, parameters)
        return response
    
    def collect_product_review(self, product_review_template, reviews):
        for review in reviews:
            new_product_n_review = product_review_template.copy()
            product_review_template['review_user_id'] = review['writer_id']
            product_review_template['review_status'] = review['status']
            product_review_template['review_text'] = review['review']['comment']
            product_review_template['review_star_durability'] = review['review']['star_durability']
            product_review_template['review_star_design'] = review['review']['star_design']
            product_review_template['review_star_cost'] = review['review']['star_cost']
            product_review_template['review_star_delivery'] = review['review']['star_delivery']
            product_review_template['review_star_avg'] = review['review']['star_avg']
            product_review_template['product_info_id'] = review['production_information']['id']
            product_review_template['production_info_name'] = review['production_information']['name']
            product_review_template['production_info_brand_name'] = review['production_information']['brand_name']
            product_review_template['production_info_explain'] = review['production_information']['explain']
            product_review_template['production_info_is_purchased'] = review['production_information']['is_purchased']
            
            self.product_n_reviews.append(new_product_n_review)
        
    def collect(self):
        self.products = list()
        self.product_n_reviews = list()
        if (self.house_warming_product_ids is None) or (len(self.house_warming_product_ids) <= 0):
            return
        
        for product_id in self.house_warming_product_ids:
            response = self.get_product_detail(product_id)
            if (response['production'] is not None) and (len(response['production']) > 0):
                self.collect_production(response['production'])
                
                current_page = 1
                response = self.get_production_review_data_by_page(self.products[len(self.products) - 1]['id'], current_page)
                if (response['reviews'] is not None) and (len(response['reviews']) > 0):
                    self.collect_product_review(self.products[len(self.products) - 1], response['reviews'])

                total_page = self.calculat_total_page(response['count']) # count: 현재 제품의 모든 리뷰 갯수
                print('>> This product has total_page:', total_page)
                if current_page is total_page:
                    continue

                while (current_page <= total_page):
                    current_page = current_page + 1
                    print('>> Collect reviews at page:', current_page)
                    response = self.get_production_review_data_by_page(product_id, current_page)
                    if (response['reviews'] is not None) and (len(response['reviews']) > 0):
                        self.collect_product_review(self.products[len(self.products) - 1], response['reviews'])
                    sleep(3)

# %%
house_warming_product_crawler = ProductCrawler(house_warming_product_ids = house_warming_product_ids, house_warming_df = df)
house_warming_product_crawler.collect()
# Out:
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 1
# >> This product has total_page: 6
# >> Collect reviews at page: 2
# [ERROER]Can not receive response
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-c36b21b435c8> in <module>
#       1 house_warming_product_crawler = ProductCrawler(house_warming_product_ids = house_warming_product_ids)
# ----> 2 house_warming_product_crawler.collect()
#
# <ipython-input-9-7907b2ccf431> in collect(self)
#      89                     print('>> Collect reviews at page:', current_page)
#      90                     response = self.get_production_review_data_by_page(product_id, current_page)
# ---> 91                     if (response['reviews'] is not None) and (len(response['reviews']) > 0):
#      92                         self.collect_product_review(self.products[len(self.products) - 1], response['reviews'])
#      93                     sleep(3)
#
# KeyError: 'reviews'

# %%
house_warming_product_crawler.product_n_reviews
# Out:
# [{'id': 106711,
#   'name': 'patagonia black hole 90l duf',
#   'review_count': 1,
#   'review_average': 5.0,
#   'scrap_count': 2,
#   'view_count': 378},
#  {'id': 38184,
#   'name': '스톰트루퍼 알람시계',
#   'review_count': 4,
#   'review_average': 4.5,
#   'scrap_count': 43,
#   'view_count': 686},
#  {'id': 38184,
#   'name': '스톰트루퍼 알람시계',
#   'review_count': 4,
#   'review_average': 4.5,
#   'scrap_count': 43,
#   'view_count': 686,
#   'review_user_id': 1241803,
#   'review_status': '확인완료',
#   'review_text': '인테리어 소품으로도 만족도가 높아요 ㅎ',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 38184,
#   'production_info_name': '스톰트루퍼 알람시계',
#   'production_info_brand_name': '레고 스타워즈',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 38184,
#   'name': '스톰트루퍼 알람시계',
#   'review_count': 4,
#   'review_average': 4.5,
#   'scrap_count': 43,
#   'view_count': 686,
#   'review_user_id': 1034459,
#   'review_status': '확인완료',
#   'review_text': '스톰트루퍼 레고시계는 화이트인테리어와도 잘 어울려서 만족스러워요~~~',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 38184,
#   'production_info_name': '스톰트루퍼 알람시계',
#   'production_info_brand_name': '레고 스타워즈',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 38184,
#   'name': '스톰트루퍼 알람시계',
#   'review_count': 4,
#   'review_average': 4.5,
#   'scrap_count': 43,
#   'view_count': 686,
#   'review_user_id': 5980427,
#   'review_status': '확인완료',
#   'review_text': '모닝벨 몇년째 저와 함께 하고 있어요 , 너무 귀여워서 완전 추천해요 ㅎㅎㅎㅎ',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 38184,
#   'production_info_name': '스톰트루퍼 알람시계',
#   'production_info_brand_name': '레고 스타워즈',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 75809,
#   'name': 'Avellino 수납형 패브릭 소파베드',
#   'review_count': 5,
#   'review_average': 3.95,
#   'scrap_count': 388,
#   'view_count': 11535},
#  {'id': 75809,
#   'name': 'Avellino 수납형 패브릭 소파베드',
#   'review_count': 5,
#   'review_average': 3.95,
#   'scrap_count': 388,
#   'view_count': 11535,
#   'review_user_id': 2186610,
#   'review_status': '확인완료',
#   'review_text': '주문일 8.27일  배송일 9.12일 대전인데도 배송이 16일 걸렸네요.\n배송예정일을 대략 알고자 3일간 10번넘게  아리아\n퍼니처에 통화 시도했지만 통화량이 많아 통화가 어렵다는 거짓안내몐트만 계속 나옵니다.\n기사님 오후2시에 배송된다는 사전연락  받고 회사 휴가내고 집에서 기다리는데  기사님 13시경 전화와서 서랍이 누락발송돼서 저녁늦게 도착된다고 합니다.  기사님 밤늦게 조립하고 수고했지만 시간촉박으로 바퀴조립에 성의가 부족함.',
#   'review_star_durability': 3,
#   'review_star_design': 3,
#   'review_star_cost': 3,
#   'review_star_delivery': 1,
#   'review_star_avg': 2.5,
#   'product_info_id': 75809,
#   'production_info_name': 'Avellino 수납형 패브릭 소파베드',
#   'production_info_brand_name': '아리아퍼니쳐',
#   'production_info_explain': '본품',
#   'production_info_is_purchased': True},
#  {'id': 75809,
#   'name': 'Avellino 수납형 패브릭 소파베드',
#   'review_count': 5,
#   'review_average': 3.95,
#   'scrap_count': 388,
#   'view_count': 11535,
#   'review_user_id': 7668475,
#   'review_status': '확인완료',
#   'review_text': '여러모로 디자인과 실용성은 확실히 좋아요.\n그런데 배송이 엄청 늦는편이고 수납공간이 조립식이다보니 생각보다 깔끔하진 않아요. 휠이있진 않아서 물건 많이 넣으면 빼기 어려워서 가벼운 옷가지 몇개만 넣어두셔야해요.',
#   'review_star_durability': 3,
#   'review_star_design': 4,
#   'review_star_cost': 2,
#   'review_star_delivery': 1,
#   'review_star_avg': 2.5,
#   'product_info_id': 75809,
#   'production_info_name': 'Avellino 수납형 패브릭 소파베드',
#   'production_info_brand_name': '아리아퍼니쳐',
#   'production_info_explain': '본품',
#   'production_info_is_purchased': True},
#  {'id': 75809,
#   'name': 'Avellino 수납형 패브릭 소파베드',
#   'review_count': 5,
#   'review_average': 3.95,
#   'scrap_count': 388,
#   'view_count': 11535,
#   'review_user_id': 1935583,
#   'review_status': '확인완료',
#   'review_text': '티비 선반을 안놓기로 했더니 물건 넣어들 곳이 필요해서 수납 가능한 쇼파베드로 구매했는데 깔끔하고 짱짱한 내구성 좋아요\n패브릭이라 아주 작은 올 빠짐이 있는데 가위로 살짝 컷 ㅎㅎ\n실용적으로 잘 사용하고 있어용',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 75809,
#   'production_info_name': 'Avellino 수납형 패브릭 소파베드',
#   'production_info_brand_name': '아리아퍼니쳐',
#   'production_info_explain': '본품',
#   'production_info_is_purchased': True},
#  {'id': 75809,
#   'name': 'Avellino 수납형 패브릭 소파베드',
#   'review_count': 5,
#   'review_average': 3.95,
#   'scrap_count': 388,
#   'view_count': 11535,
#   'review_user_id': 6121565,
#   'review_status': '확인완료',
#   'review_text': '* 배송도 빨랐구요 (주말포함 일주일 정도)\n배송기사님 너무 너무 친절하시고 꼼꼼하게 설치해주셨어요\n한덩치하는 우리남편 (키: 183/ 몸무게: 거의 백)\n침대로 사용하는데 무리없습니다\n색상도 너무 어둡지않아 이뽀요!\n너무 잘 산거같아 뿌듯합니다',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 75809,
#   'production_info_name': 'Avellino 수납형 패브릭 소파베드',
#   'production_info_brand_name': '아리아퍼니쳐',
#   'production_info_explain': '본품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 1653796,
#   'review_status': '확인완료',
#   'review_text': '딸램이 전유물인양 좋아하네요~~^^ 예뻐요~~',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '무선AIR914(무선사은품증정)',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 1254141,
#   'review_status': '확인완료',
#   'review_text': '요즘 이거 없으면 안되나봐요 ㅋㅋㅋㅋ옆집이랑 찌찌뽕',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 6373584,
#   'review_status': '확인완료',
#   'review_text': '913,914 두개다 구매 했어요\n913은 회전이 좋구요\n914는 휴대가 좋아요(회전안됨)\n무튼 저는 둘다 좋네요\n특히 수면풍이 회전이 안되도\n강약중강약 이런식으로 \n바람을 수시로 바꿔줘서\n좋은것 같아요.\n리모콘도 편리하고\n암튼 단점보다 장점이 더 많네요^^',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR913',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 32266,
#   'review_status': '확인완료',
#   'review_text': '디자인 우수! 서큘은 처음 사용하는데 강풍으로 했을때 바람이 멀리까지 전달됩니다~ 3단정도는 밤에 켜두고 잘만한듯하구요.\n\n좌우 회전도하고 상하 고정 시킬 수 있어요~ \n겨울에는 비슷한 디자인 컨셉의 플러스마이너스 히터 사용하고 여름에는 요제품 사용하면 딱일듯 ㅎㅎ\n\n무상 a/s가 2년이네요 굿굿! 리모콘도 있어서 만족스!',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '유선AIR913',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 1130677,
#   'review_status': '확인완료',
#   'review_text': '컴팩트 사이즈에 디자인이 너무 예뻐요 ˃̶᷄‧̫ ˂̶᷅๑ 원룸에서 사용할 적당한 크기의 선풍기를 찾다가 우연히 이 써큘레이터를 보고 구매했는데 진짜... 최고입니다 인테리어도 해치지 않고 무선이라 편리해요 뭣보다 소음이 정말 적어서 사용하기 최고네요 좋아요 !',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '무선AIR914(무선사은품증정)',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 6373584,
#   'review_status': '확인완료',
#   'review_text': '이동성도 좋고 시원하네요^^\n아이가 밤에 틀어달라해서\n수면풍으로 틀어줬는데\n금방 잠들었어요.\n장점은 무선이라 이동성 좋고\n단점은 회전안되요.\n913이 회전되고 유선이예요\n참고하세요.\n저는 두개 다샀어요 ㅎㅎ',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR914',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 1284194,
#   'review_status': '확인완료',
#   'review_text': '디자인, 기능 다 맘에들어요 에어컨 틀기는 춥고 요즘 날씨에 틀기 딱좋네요',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '무선AIR914(무선사은품증정)',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 2943832,
#   'review_status': '확인완료',
#   'review_text': '넘 귀엽고 예쁘고 깔끔해요\n\n🐻 디자인\n좁은 원룸이라 선풍기는 너무 크고 부담스러워서 서큘레이터를 찾고 있었는데 다 디자인이 너무 투박하고 이상했는데 이건 디자인 최고입니다🥺\n그리고 화이트 색상으로만 이루어져있고 전체적인 디자인이 정말 깔끔하고 예뻐요 덕분에 더 시원한 느낌이에요\n\n🐻 크기\n크기도 너무 크지도 작지도 않고 딱 적당합니다 원룸또는 좁은 방에서 쓰기 딱 좋아요\n\n🐻 바람, 소리\n바람도 정말 시원해요! 전 약하게 바람 트는 걸 좋아하는데 딱 좋아요 소리는 그냥 일반 평범한 선풍기를 비슷한 거 같아요 엄청 조용하지도 않고 시끄럽지도 않는 그냥 평범한 선풍기 소리 정도! \n제일 약하게 틀면 정말 조용한 편이고 강도를 높이면 소리가 좀 커져요 전 별로 신경 안쓰였습니다\n\n🐻 무선 충전\n무선이라 선이 치렁치렁 있지 않아서 미관상 더 깔끔해 보여 좋아요 충전기는 그냥 핸드폰 충전기 선처럼 얇아서 충전하고 있어도 딱히 더러워보이지 않아요 무엇보다 충전하면서 쓸 수 있어서 좋아요! \n한 번 충전하면 막 엄청 오래가는 거는 아니지만 막상 써보니까 나름 오래 가는 것 같고 충전하는게 그렇게 귀찮지 않아요! 충전하면서 쓸 수 있어서 더 그러는 것 같아요 평소에 약하게 틀기 때문에 하루동안은 잘 씁니다\n\n\n다만 저 하얀 불빛이 밤에는 좀 밝더라구요 ㅠㅠ\n좀 멀리 두거나 천으로 덮어두고 자요\n\n\n\n',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 1665137,
#   'review_status': '확인완료',
#   'review_text': '에어컨 바람을 안좋아하는데 갑자기 더워지는 바람에 급하게 주문했어요!!\n발송 바로 해주셔서 좋았고 따로 조립 필요없이 바로 사용할수있어서 정말 편했어요!\n디자인은 깔끔해서 좋은데 외형에서 약간 저렴한 티는 나네용\n리모컨 있는거 진짜 짱편하고 좋습니다 !!',
#   'review_star_durability': 4,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 4.75,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 6999059,
#   'review_status': '확인완료',
#   'review_text': '디자인 가성비 세기 다 너무 좋습니다~~~',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 5221389,
#   'review_status': '확인완료',
#   'review_text': '배송빨라요!\n작동도 잘되구요 , 리모콘이 있어서 너무 편리해요\n방에서 쓸 용도로 찾았는데 자리차지 많이 안하고 ,\n바람세기 6단까지 조절되구요 상하 좌우 다 움직여요 가성비 최고!\n디자인도 깔끔하고 예뻐용\n',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 3892635,
#   'review_status': '확인완료',
#   'review_text': '회전이나 단계별 조절 그리고 타이머 등 너무 마음에 들고 제일 마음에 드는건 가격이랑 디자인이에요!\n소음은 수면모드나 1-2단계에서는 굳뜨\n',
#   'review_star_durability': 3,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 4,
#   'review_star_avg': 4.25,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 3097302,
#   'review_status': '확인완료',
#   'review_text': '생각보다 커서 놀랬지만 디자인이 너무 깔끔하고 맘에 드네요 그리고 이 정도 큰게 더 나은 것 같아요 리모컨도 있다는 것이 맘에 드네요 6단계까지 있어서 산건데 바람세기도 충분히 세고 에어컨이랑 같이 틀면 환상이겠어요 이번 여름 잘 보내야할텐데 애옹이들이랑 잘 쓰겠습니다',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 3573848,
#   'review_status': '확인완료',
#   'review_text': '가격두 저렴하구 크기도 괜찮아요 다만 3단으로 했을때 소음은 꽤 큽니다',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 2123398,
#   'review_status': '확인완료',
#   'review_text': '사진은 충전하고 있는 모습인데 무선,유선으로 쓸 수 있어서 아주 좋습니다.  집에 유선 서큘이 하나 있어서 무선 기능 하나 보고 구매했는데 만족합니다.  무선이라는 강력한 이점이 없다면, 이 제품은 일단 플라스틱 재질의 개선이 필요해 보입니다. 집에 있는 비슷한 가격의 서큘과 비교해 보면 재질이 확실히 떨어져요. 그리고 이 제품 한정 뽑기가 잘못된 건지는 몰라도 3단 정도부터 벌써 덜덜 거리는 소리가 납니다. 2단 정도도 약미풍 정도는 되기 때문에 평소 사용에 큰 불편은 없겠지만 그래도 아쉽죠.  \n며칠 더 써 본 후 다시 남깁니다  - 배터리가 오래 가고 무선의 장점이 다른 모든 걸 이깁니다. ',
#   'review_star_durability': 4,
#   'review_star_design': 5,
#   'review_star_cost': 4,
#   'review_star_delivery': 5,
#   'review_star_avg': 4.5,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 8029861,
#   'review_status': '확인완료',
#   'review_text': '친구 집들이 선물 해줬는데 맘에들어해서 다행이에용💚 모가지도 잘돌아가고 시원하다구 하네요^~^\n리모컨도 있어서 편한거같아용!!',
#   'review_star_durability': 4,
#   'review_star_design': 4,
#   'review_star_cost': 4,
#   'review_star_delivery': 4,
#   'review_star_avg': 4.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 1906743,
#   'review_status': '확인완료',
#   'review_text': '싼맛에 쓰기좋아요 \n강하게 해야 공기순환되는것같은데 \n강하게 틀면 소음 심해요 \n그리고 앞부분에 미세한 흠집있는데 교환하기 귀찮아서 걍 쓸게요 ',
#   'review_star_durability': 3,
#   'review_star_design': 5,
#   'review_star_cost': 3,
#   'review_star_delivery': 5,
#   'review_star_avg': 4.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 8038016,
#   'review_status': '확인완료',
#   'review_text': '완전 대박이예요~\n저희집이 주택4층이라 많이 더워서  에어컨 틀어도 시원하지않아서 반신반의 하며 싸게 나왔길래 구입했는데~\n완전 강추드려요~~\n시원하다못해 추덥라구요ㅎㅎ',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 5186656,
#   'review_status': '확인완료',
#   'review_text': '귀엽고 시원합니다~가격도 저렴하게 서큘 겸 선풍기로 잘 사용 할 것 같습니다. 제가 중점적으로 본 것은...회전이 될 것. 자연풍. 타이머. 직각으로 위로 올려서 위로 바람을 순환 시킬 수 있을 것...이었습니다!! 모두 만족하는 제품이에요~ 무선도 좋지만, 회전이 더 필요해서 유선으로 구매 했습니다~~ㅎㅎ만족해요~소리는...제가 느끼기엔 3단부터 소리가 인지 됩니다. 참고하세요~~❤ 리모컨은 완전 사랑입니다~~ㅎㅎ',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 3869001,
#   'review_status': '확인완료',
#   'review_text': '사무직으로 일해서 앉아있는 시간이 많은\n저한테 딱 맞는 제품이에요 \n가격도 저렴하고, 디자인이 심플하고 너무 마음에 들어요 \n저는 책상 밑에 놓고 다리쪽으로 바람오길바라고 구매했는데 딱이에요\n회전 기능도 딱히 필요없었는데 이 제품은 기본에 충실한 제품같아요. 가격대비 바람도 쎄고 즇아요 \n한가지 단점이라면 3단계로 했을때 소리가 엄청 큰건데 \n조용한 장소라면 단점이 될수도 있을것 같아요 \n제가 일하는 곳은 소음이 약간 있어서 딱 입니당',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 6812926,
#   'review_status': '확인완료',
#   'review_text': '디자인 이쁩니다 옆으로 회전이 안되는건 아쉬워요',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 3584648,
#   'review_status': '확인완료',
#   'review_text': '처음 왔을때 불량이 왔는지 회전할때 드르륵 소리가 굉장히 심하더라구요 바로 카톡으로 말씀드리고  맞교환 해서 왔는데 재대로 왔네요 소리 안나고 바람도 시원하고 생각했던대로 잘쓰고 있으요~ 배송도 빠르고 다만 쓰다가, 또 소음 난다는 후기를 보고 저도 그럴까봐 박스는 못버리고 있어요~!!  그리고 상담해주신 상담사님 친절하게 해주셔서 감사합니다^^',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 4530532,
#   'review_status': '확인완료',
#   'review_text': '회전빼고는 무선이라서 좋아요 자유롭게 이동가능최고\n디자인도 사이즈 색상 가볍고 맘에들어요 가격은 조금 비싼느낌이네요 고장없이 오래함께하면 좋을거같아요',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 4,
#   'review_star_delivery': 5,
#   'review_star_avg': 4.75,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 7684538,
#   'review_status': '확인완료',
#   'review_text': '디자인도 일단 너무 예쁘고 마음에 들어요 ! 이제 여름이라 바로 주문했어요!',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 5638082,
#   'review_status': '확인완료',
#   'review_text': '갑자기 너무 더워져서 ;;;\n디자인도 이쁘고 시원하네용',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 4102134,
#   'review_status': '확인완료',
#   'review_text': '주방 전용으로 구입.\n많이 작은 편 아니지만, \n디자인과 컬러 만족.\n무선, 리모컨 기능 필요없는 사람이라\n단순한 기능만 있는게 마음에 듦.',
#   'review_star_durability': 4,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 4,
#   'review_star_avg': 4.5,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 6373584,
#   'review_status': '확인완료',
#   'review_text': '유선무선 둘다 넘나좋아요\n유선은 회전되고 무선은 회전 안되요',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 4517904,
#   'review_status': '확인완료',
#   'review_text': '깔끔하니 좋네요 제 기능에도 충실합니다',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 4,
#   'review_star_delivery': 5,
#   'review_star_avg': 4.75,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR913',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 1671572,
#   'review_status': '확인완료',
#   'review_text': '1.2.3단은 선선한바람이라 평소에 사용하기 좋고 4.5.6단은 엄청나게 강한 바람이라 여름에 진짜 좋을것 같아요 ㅎㅎ 소리도 생각보다 적고 회전도 잘되서 정말 만족합니다!!!',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR913',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 2569684,
#   'review_status': '확인완료',
#   'review_text': '디자인도 깔끔하고, 리모컨이 말도 잘 들어요!\n바람의 세기가 여러단계라 너무 좋아요!\n자취방에 엄마가 오셨다가 엄마도 하나 사달라고 하셔서 보내드렸어요!\n저희집 아깽이도 좋아서 여름내내 선풍기랑 같이 잤답니당',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR1402',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 4003197,
#   'review_status': '확인완료',
#   'review_text': '원룸이라 빨래건조할때만 사용하고있어요 아기자기하고 귀엽네용',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR911',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 3655249,
#   'review_status': '확인완료',
#   'review_text': '쎄게틀면 소음이있긴한데 가성비좋은거같아요 리모컨도 아주잘먹어요!',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR913',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 4502375,
#   'review_status': '확인완료',
#   'review_text': '사이즈 너무 좋아요 귀녑고 시원한 바람 가격대비 만족스러운 쇼핑입니다',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR913',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 2241926,
#   'review_status': '확인완료',
#   'review_text': '깔끔하고 바람도 세서 좋아용 !!^^ 두개 더 사려구용 ',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR911',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 3005627,
#   'review_status': '확인완료',
#   'review_text': '사용하기전 리모컨필름을제거해서 반품못하고 싼가격이라 쓸건데요 솔직히 반품하고싶을정도로 소음있어요 돈조금더주고 다른제품사고싶을정도에요 진짜 평이 왜좋은줄모르겠네요 ㅠ',
#   'review_star_durability': 1,
#   'review_star_design': 4,
#   'review_star_cost': 3,
#   'review_star_delivery': 5,
#   'review_star_avg': 3.25,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR913',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 2017192,
#   'review_status': '확인완료',
#   'review_text': '대만족!!!!!!! 유선 상품으로 구입했어요!이사오면서 기존 선풍기는 부피가 너무 커서 새로 구매하게 되었는데요~ 써큘레이터는 별로 시원하지 않다는 얘기가 있어서 좀 걱정했지만 블로그로 해당 상품을 찾아보니 타사이트보다 만원이상 저렴한 최저가고 블로그 후기에 제품이 회전하는 동영상을보고 일단 샀습니다. 배송도 빠르고 부피도 많이 차지하지않아 사용하던 테이블에 올려쓸수있고 디자인도 예뻐소 혼자 회전하면서 일하는 써큘레이터가 귀엽네요 ㅎㅎ 작동해보니 회전하는 날개 폭이 작아서 그렇지 선풍기보다 시원하규 리모컨도 있어 엄청 편리할것 같아요! ',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR913',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 3560879,
#   'review_status': '확인완료',
#   'review_text': '첨에 무선을 구입했는데 잔기스가 넘  많아 반품했어요 회전이 수동이라는게 별루였구요 다시 913으로 구매했는데 생각보다 시원하지도 않아요 소음도 있구요 전 그냥 화장대에 놓고 쓰려고 주문햣어요무선보다 유선 추천드려요 가성비가 훨 좋아요 ',
#   'review_star_durability': 3,
#   'review_star_design': 4,
#   'review_star_cost': 2,
#   'review_star_delivery': 5,
#   'review_star_avg': 3.5,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR913',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 3682417,
#   'review_status': '확인완료',
#   'review_text': '"이정도는 그냥 따지지않고 쓰겠지"\n라고 생각하며 포장한 듯 하네요\n제품 자체는 풍량이 생각보다 약하긴하지만\n선풍기가 아니라 서큘레이터니까요.\n배터리는 금방 소모되는 듯 하지만 그때그때 충전하면 쓸정도 되구요.\n방 이곳저곳 이동성이 쉽고 가벼워서 좋아요.',
#   'review_star_durability': 5,
#   'review_star_design': 4,
#   'review_star_cost': 5,
#   'review_star_delivery': 3,
#   'review_star_avg': 4.25,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR914',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 2019152,
#   'review_status': '확인완료',
#   'review_text': '회전도 안되고 소리는 시끄럽고 충전을해도 오래가는지 모르겠고 전 별로네요',
#   'review_star_durability': 3,
#   'review_star_design': 3,
#   'review_star_cost': 3,
#   'review_star_delivery': 3,
#   'review_star_avg': 3.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR914',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 4350488,
#   'review_status': '확인완료',
#   'review_text': '가벼워요~ 이동하기 쉽고 동작도 어렵지않네요~\n충전할 때 코드가 금방 뜻거워져요.. \n디자인도 이쁘고 만족합니다.\n구입 전 회전되는지 않되는지 \n잘 보고 구입하세요^^\n전 타이머랑 이동성 생각해서 무선으로 구입했어요!',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': 'AIR914',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 1377823,
#   'review_status': '확인완료',
#   'review_text': '좁은 평수에서 쓰기 좋아요 \n저는 무선제품으로 사서 더 편하게 갖다두고 쓰기 좋을거같습니다.\n\n중요한건 자동회전이 안돼요! 손으로 일일이 꺾어나 돌려야함. \n\n당연히 되는줄알았어요 서큘레이터니까..\n솔직히 이 점은 정말 불편하겠네요. \n지혼자 안돌아가니 한군데만 바람쐴수밖에 없네요. \n빨래말릴 때도 돌아가게두고 써야하는데 말이죠.. 왜이렇게 만들었을까',
#   'review_star_durability': 4,
#   'review_star_design': 5,
#   'review_star_cost': 4,
#   'review_star_delivery': 5,
#   'review_star_avg': 4.5,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '무선AIR914(무선사은품증정)',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 4183549,
#   'review_status': '확인완료',
#   'review_text': '-배송은 엄청 빨리옴👍🏻  중간 은색부분에 스크레치같은게 있는데 물티슈로 닦아도 안지워짐...교환할까하다 귀찮아서 걍씀....  취침모드해도 바람소리는 좀 들리는편..소리에 예민한사람들은 거슬릴수도..    디쟌은 겁나 깔끔하고 만족쓰',
#   'review_star_durability': 4,
#   'review_star_design': 5,
#   'review_star_cost': 4,
#   'review_star_delivery': 5,
#   'review_star_avg': 4.5,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '무선AIR914(무선사은품증정)',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 2810503,
#   'review_status': '확인완료',
#   'review_text': '크기도 아담하고 디자인은 전말 맘에들어요 리모컨도 간단하고 편리해요 바람세기는 1부터4단까지는 안거슬리는데 그 이상부터 소리는 꽤 세네요 소린큰데 바람이 엄청시원한건 아녜요 이쁘면됐죠 ㅎㅎ',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 4,
#   'review_star_delivery': 4,
#   'review_star_avg': 4.5,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '유선AIR913',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 1827617,
#   'review_status': '확인완료',
#   'review_text': '디자인도 너무 이쁘고 작동방법도 간단하구 마음에 듭니당><',
#   'review_star_durability': 4,
#   'review_star_design': 5,
#   'review_star_cost': 4,
#   'review_star_delivery': 4,
#   'review_star_avg': 4.25,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '무선AIR914(무선사은품증정)',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 1659838,
#   'review_status': '확인완료',
#   'review_text': '만족합나디 크기도 적당하고 좋네요 감사합니다',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '무선AIR914(무선사은품증정)',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 1653796,
#   'review_status': '확인완료',
#   'review_text': '좋아요 바람이 그리세진않지만 침실에 또는 아이용으로 사용하기좋아요~ 무선이라 편하기도하구요',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 3298339,
#   'review_status': '확인완료',
#   'review_text': '디자인도 너무 이쁘고 특히 보관할수 있는 가방이 있어서 너무 좋아요~! 내년 여름에 하나 다 구매할까 합니다!',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 4,
#   'review_star_delivery': 5,
#   'review_star_avg': 4.75,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 2109194,
#   'review_status': '확인완료',
#   'review_text': '여름캠핑때 엄청 잘사용햇어요!!!!!',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 8916572,
#   'review_status': '확인완료',
#   'review_text': '여름 내내 잘 썼습니다 하루 종일 방안 공기 순환에도 도움 되었네요',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 2832997,
#   'review_status': '확인완료',
#   'review_text': '늦은 리뷰지만 여름에 놀러가서 저 선풍기 없었으면 큰일날뻔 작지만 나름 좋아용\U0001f90d',
#   'review_star_durability': 4,
#   'review_star_design': 5,
#   'review_star_cost': 4,
#   'review_star_delivery': 4,
#   'review_star_avg': 4.25,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 290553,
#   'review_status': '확인완료',
#   'review_text': '예뻐서 샀어요 충전하면 무선으로 쓸 수 있어서 좋아요. ',
#   'review_star_durability': 4,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 4,
#   'review_star_avg': 4.5,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 8643592,
#   'review_status': '확인완료',
#   'review_text': '사이즈도 원룸에 딱이고 와우 넘 추움 제일 작은 걸로 틀어도 나같이 몸에 열 많은 사람 굿굿 근데 소리 좀 나여',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 5818428,
#   'review_status': '확인완료',
#   'review_text': '여름철 이동도 편하고 요긴하게 사용했네요^^',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 222567,
#   'review_status': '확인완료',
#   'review_text': '소음이 좀 있고 바람이 약해요\n여름에는 이거 하나로는 힘들어요.\n저는 환기시키고 공기 순환하거나 주방에서 더울때 사용해요. 무선이라 편하긴합니다',
#   'review_star_durability': 4,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 4.75,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 4520506,
#   'review_status': '확인완료',
#   'review_text': '일반 선풍기는 수납 자리를 너무 차지하는데 작고 사각형이라 보관할 때도 편리해요. 바람이 막 엄~~청 세지는 않은데 작은 방이나 원룸에는 충분해요.',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 5286398,
#   'review_status': '확인완료',
#   'review_text': '시원하네요 겨울에 이걸로 빨래말리면 되겠어요 ㅎㅎ',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 3,
#   'review_star_avg': 4.5,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 4062034,
#   'review_status': '확인완료',
#   'review_text': '회전이 안되는 거 빼고는(몰랐어요;) 좋습니다~\n일단 디자인이 매우 예뻐요~ 깔끔하고 귀엽고.\n바람도 부드럽고 일단 갖고 이동하기가 넘 좋아요ㅎㅎㅎ 1인이 사용하기엔~👍ㅎㅎㅎ',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 8532916,
#   'review_status': '확인완료',
#   'review_text': '배터리 조루 에요 ㅠ^ㅜ\n차라리 유선용이 나을듯 ㅠ',
#   'review_star_durability': 1,
#   'review_star_design': 3,
#   'review_star_cost': 1,
#   'review_star_delivery': 3,
#   'review_star_avg': 2.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 6393821,
#   'review_status': '확인완료',
#   'review_text': '쬐꼼한게  아쥬 열일합니다\n디자인 이쁘고  기능도 아주 좋아요\n혼자 사시는 분들께 강추!!',
#   'review_star_durability': 4,
#   'review_star_design': 4,
#   'review_star_cost': 4,
#   'review_star_delivery': 5,
#   'review_star_avg': 4.25,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 6544830,
#   'review_status': '확인완료',
#   'review_text': '시원하고 예쁘고 좋아요 마음에 드네요 ',
#   'review_star_durability': 4,
#   'review_star_design': 4,
#   'review_star_cost': 4,
#   'review_star_delivery': 4,
#   'review_star_avg': 4.0,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 3367179,
#   'review_status': '확인완료',
#   'review_text': '작고 심플하고 예뻐요\n무선 사용할 일이 없을 것 같았는데 막상 있으니깐 선 빼고 많이 옮겨서 쓰게 되더라구요\n집에서 빨래 말릴 때도 좋습니당ㅋㅋ\n다만 최고 풍속일 때는 거스릴 정도로 소리가 좀 크네요\n최대로는 그래서 잘 안해요 \n만족하고 좋아요',
#   'review_star_durability': 4,
#   'review_star_design': 5,
#   'review_star_cost': 4,
#   'review_star_delivery': 5,
#   'review_star_avg': 4.5,
#   'product_info_id': 282241,
#   'production_info_name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'production_info_brand_name': '솔러스에어',
#   'production_info_explain': '단품',
#   'production_info_is_purchased': True},
#  {'id': 282241,
#   'name': '무선 스퀘어 대용량 배터리 써큘레이터 AIR914BFW (보관가방 증정)',
#   'review_count': 716,
#   'review_average': 4.54,
#   'scrap_count': 6417,
#   'view_count': 20518,
#   'review_user_id': 5789535,
#   'review_status': '확인완료',
# ...
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 1008454,
#   'review_status': '확인완료',
#   'review_text': '행주말고도 활용도가 높아서 좋아요 저는 가리개로 쓰고있어요',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '블루_201.724.44',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 5129114,
#   'review_status': '확인완료',
#   'review_text': '주방에서 손딲는 행주로 써도 좋고 식탁보로 써도 예뻐요:) 북유럽스러운 디자인도 너무 맘에 듭니다♡. 저는 2세트 쿠매했어요~ㅎ',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 1009039,
#   'review_status': '확인완료',
#   'review_text': '깔끔하니 좋아요. 실물과 사진 색이 동일합니당 :)',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '그린_202.777.66',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 3565026,
#   'review_status': '확인완료',
#   'review_text': '행주가 거기서 거기지만 이건 그냥 짱짱 하고 예뻐서 좋아요',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 1215823,
#   'review_status': '확인완료',
#   'review_text': '덮개로 쓰기 너무 좋아요 가성비 좋은 제품입니다.',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 569632,
#   'review_status': '확인완료',
#   'review_text': '오래사용해도 질리지않고 무난하고 깔끔해요\n덮개로 사용하기도하고 키친크로스로도 제격이에요',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '블루_201.724.44',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 4518814,
#   'review_status': '확인완료',
#   'review_text': '저렴한 가격에 4장을 세트로! 다른색도 구매하고 싶습니다ㅎㅎ',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 306227,
#   'review_status': '확인완료',
#   'review_text': '심플하고 이뻐서 맘에 들어요 행주 대신 가리기용',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '블루_201.724.44',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 1010101,
#   'review_status': '확인완료',
#   'review_text': '이래저래 쓰일 일이 많은 행주입니다.',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 49886,
#   'review_status': '확인완료',
#   'review_text': '가격도 저렴하고 디자인도 예뻐서 행주로 사용하기도 하지만 꾸미기 소품으로 사용하기에도 좋아요',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 1735482,
#   'review_status': '확인완료',
#   'review_text': '화장대 위에 깔아두니 분위기가 살아요.',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '블루_201.724.44',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 1034929,
#   'review_status': '확인완료',
#   'review_text': '토스트기 덮개, 테이블매트로 절 쓰고있어요',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '블루_201.724.44',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 873629,
#   'review_status': '확인완료',
#   'review_text': '무난하고 여기저기 잘어울리고 저렴한 키친클로스에요. 협탁에 깔아두기도 하고 부엌에서 쓰기도 하고 예쁩니당',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 718319,
#   'review_status': '확인완료',
#   'review_text': '행주로는 못쓰고 있고 가림막이나 이런식으로 덮개나 깔아두는 용도로 쓰고 있어요.',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '그린_202.777.66',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 1144944,
#   'review_status': '확인완료',
#   'review_text': '깔끔하게 사용할수있어서 좋아요 근데 색상이 사진보다는 좀 연해요~',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '블루_201.724.44',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 1748506,
#   'review_status': '확인완료',
#   'review_text': '가전커버로도좋고 냄비받침대로도좋고 여기저기에 쓰여요 가격도 싸고 잘샀어요',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 1682987,
#   'review_status': '확인완료',
#   'review_text': '디자인이 심플해서 잘 사용하게되는 제품이에요',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 1096018,
#   'review_status': '확인완료',
#   'review_text': '너무 예뻐요 사진보다 훨씬나은데!!! 제가 잘 못찍어서 안타까워요 ㅠㅠ 강추!!',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '그린_202.777.66',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 947509,
#   'review_status': '확인완료',
#   'review_text': '가성비 진짜 좋아요.\n산지 오래 됐는데 테이블러너로도 쓰고 전자레인지 덮개로도 쓰고 요번엔 이사한 집 주방 서랍이 찝찝해서 바닥에 깔고 그릇 놨어요',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '블루_201.724.44',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 610392,
#   'review_status': '확인완료',
#   'review_text': '여기저기 가림막으로 잘 쓰고 있어요. 디자인 무난하고 좋아요. 흡수력은 그저그래서 행주보다는 인테리어소품용으로 쓰고있습니다',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '블루_201.724.44',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 900688,
#   'review_status': '확인완료',
#   'review_text': '너무 예뻐서 행주로 쓰기 너무 아까운 제품...\n가성비 갑!!!',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 705980,
#   'review_status': '확인완료',
#   'review_text': '핸드타월로 쓰고있는데 빳빳하니 좋으네요. 먼지도없고',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '그린_202.777.66',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 1059574,
#   'review_status': '확인완료',
#   'review_text': '가성비 갑쓰!\n깔끔한 디자인에 삶아서 사용 가능한 소재로 위생적으로 사용 가능해요.',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '블루_201.724.44',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 1029514,
#   'review_status': '확인완료',
#   'review_text': '저렴하고 예뻐요 여기저기 요긴하게 잘 쓰고 있어요 !',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '블루_201.724.44',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 2237040,
#   'review_status': '확인완료',
#   'review_text': '이케아 가면 무조건 사야하는 행주!!! 4장 다 무늬가 달라서 좋아요😊',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 1956974,
#   'review_status': '확인완료',
#   'review_text': '배송 잘 받았습니당~ㅎ깔끔하고 좋아용 !',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '블루_201.724.44',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 546348,
#   'review_status': '확인완료',
#   'review_text': '질고 좋고 저렴해서 너무 돟았어요~~!!',
#   'review_star_durability': 5,
#   'review_star_design': 5,
#   'review_star_cost': 5,
#   'review_star_delivery': 5,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '블루_201.724.44',
#   'production_info_is_purchased': True},
#  {'id': 13524,
#   'name': 'ELLY 행주',
#   'review_count': 776,
#   'review_average': 4.69,
#   'scrap_count': 5975,
#   'view_count': 154029,
#   'review_user_id': 2581047,
#   'review_status': '확인완료',
#   'review_text': '이뻐서 행주로 안쓰고 받침으로 사용하고 있어요~ 그냥 깔아만 두어도 인테리어적으로 꽤 이뿝니다',
#   'review_star_durability': 0,
#   'review_star_design': 0,
#   'review_star_cost': 0,
#   'review_star_delivery': 0,
#   'review_star_avg': 5.0,
#   'product_info_id': 13524,
#   'production_info_name': 'ELLY 행주',
#   'production_info_brand_name': '이케아',
#   'production_info_explain': '',
#   'production_info_is_purchased': False},
#  ...]

# %%
house_warming_product_review_df = pd.DataFrame(house_warming_product_crawler.product_n_reviews)
house_warming_product_review_df.head(10)
# Out:
#        id                          name  review_count  review_average  \
# 0  106711  patagonia black hole 90l duf             1            5.00
# 1   38184                    스톰트루퍼 알람시계             4            4.50
# 2   38184                    스톰트루퍼 알람시계             4            4.50
# 3   38184                    스톰트루퍼 알람시계             4            4.50
# 4   38184                    스톰트루퍼 알람시계             4            4.50
# 5   75809         Avellino 수납형 패브릭 소파베드             5            3.95
# 6   75809         Avellino 수납형 패브릭 소파베드             5            3.95
# 7   75809         Avellino 수납형 패브릭 소파베드             5            3.95
# 8   75809         Avellino 수납형 패브릭 소파베드             5            3.95
# 9   75809         Avellino 수납형 패브릭 소파베드             5            3.95
#
#    scrap_count  view_count  review_user_id review_status  \
# 0            2         378             NaN           NaN
# 1           43         686             NaN           NaN
# 2           43         686       1241803.0          확인완료
# 3           43         686       1034459.0          확인완료
# 4           43         686       5980427.0          확인완료
# 5          388       11535             NaN           NaN
# 6          388       11535       2186610.0          확인완료
# 7          388       11535       7668475.0          확인완료
# 8          388       11535       1935583.0          확인완료
# 9          388       11535       6121565.0          확인완료
#
#                                          review_text  review_star_durability  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2                              인테리어 소품으로도 만족도가 높아요 ㅎ                     0.0
# 3             스톰트루퍼 레고시계는 화이트인테리어와도 잘 어울려서 만족스러워요~~~                     0.0
# 4        모닝벨 몇년째 저와 함께 하고 있어요 , 너무 귀여워서 완전 추천해요 ㅎㅎㅎㅎ                     0.0
# 5                                                NaN                     NaN
# 6  주문일 8.27일  배송일 9.12일 대전인데도 배송이 16일 걸렸네요.\n배송예정...                     3.0
# 7  여러모로 디자인과 실용성은 확실히 좋아요.\n그런데 배송이 엄청 늦는편이고 수납공간...                     3.0
# 8  티비 선반을 안놓기로 했더니 물건 넣어들 곳이 필요해서 수납 가능한 쇼파베드로 구매...                     5.0
# 9  * 배송도 빨랐구요 (주말포함 일주일 정도)\n배송기사님 너무 너무 친절하시고 꼼꼼...                     5.0
#
#    review_star_design  review_star_cost  review_star_delivery  \
# 0                 NaN               NaN                   NaN
# 1                 NaN               NaN                   NaN
# 2                 0.0               0.0                   0.0
# 3                 0.0               0.0                   0.0
# 4                 0.0               0.0                   0.0
# 5                 NaN               NaN                   NaN
# 6                 3.0               3.0                   1.0
# 7                 4.0               2.0                   1.0
# 8                 5.0               5.0                   5.0
# 9                 5.0               5.0                   5.0
#
#    review_star_avg  product_info_id   production_info_name  \
# 0              NaN              NaN                    NaN
# 1              NaN              NaN                    NaN
# 2              5.0          38184.0             스톰트루퍼 알람시계
# 3              5.0          38184.0             스톰트루퍼 알람시계
# 4              5.0          38184.0             스톰트루퍼 알람시계
# 5              NaN              NaN                    NaN
# 6              2.5          75809.0  Avellino 수납형 패브릭 소파베드
# 7              2.5          75809.0  Avellino 수납형 패브릭 소파베드
# 8              5.0          75809.0  Avellino 수납형 패브릭 소파베드
# 9              5.0          75809.0  Avellino 수납형 패브릭 소파베드
#
#   production_info_brand_name production_info_explain  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                    레고 스타워즈
# 3                    레고 스타워즈
# 4                    레고 스타워즈
# 5                        NaN                     NaN
# 6                     아리아퍼니쳐                      본품
# 7                     아리아퍼니쳐                      본품
# 8                     아리아퍼니쳐                      본품
# 9                     아리아퍼니쳐                      본품
#
#   production_info_is_purchased
# 0                          NaN
# 1                          NaN
# 2                        False
# 3                        False
# 4                        False
# 5                          NaN
# 6                         True
# 7                         True
# 8                         True
# 9                         True

# %%
origin_review_df = pd.read_csv('./input/data-product-review-v1.csv', sep='\t', encoding="UTF-16")
len(origin_review_df)
# Out:
# 59898

# %%
new_df = pd.concat([origin_review_df, house_warming_product_review_df])
len(new_df)
# Out:
# 98484

# %%
new_df[98483:]
# Out:
#        Unnamed: 0      id                   name  review_count  \
# 38585         NaN  388715   순수원목 A사이드테이블 3colors         28574
#
#        review_average  scrap_count  view_count  review_user_id review_status  \
# 38585            4.53        20610      162635       7101314.0          확인완료
#
#                 review_text  review_star_durability  review_star_design  \
# 38585  조립 매우쉽고 이뻐요 강추입니다~~~                     5.0                 5.0
#
#        review_star_cost  review_star_delivery  review_star_avg  \
# 38585               5.0                   5.0              5.0
#
#        product_info_id   production_info_name production_info_brand_name  \
# 38585         388715.0   순수원목 A사이드테이블 3colors                     먼데이하우스
#
#       production_info_explain production_info_is_purchased
# 38585  상품명: A사이드테이블 / 색상: 화이트                         True

# %%
new_df.to_csv("./input/data-product-review-v2.csv", sep='\t', na_rep='', encoding="UTF-16")

# %%
pd.read_csv('./input/data-product-review-v2.csv', sep='\t', encoding="UTF-16")
# Out:
# d:\program\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Unnamed: 0  Unnamed: 0.1      id  \
# 0               0           0.0  267218
# 1               1           1.0  267218
# 2               2           2.0  267218
# 3               3           3.0  267218
# 4               4           4.0  267218
# ...           ...           ...     ...
# 98479       38581           NaN  388715
# 98480       38582           NaN  388715
# 98481       38583           NaN  388715
# 98482       38584           NaN  388715
# 98483       38585           NaN  388715
#
#                                                name  review_count  \
# 0      [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)          1930
# 1      [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)          1930
# 2      [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)          1930
# 3      [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)          1930
# 4      [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)          1930
# ...                                             ...           ...
# 98479                          순수원목 A사이드테이블 3colors         28574
# 98480                          순수원목 A사이드테이블 3colors         28574
# 98481                          순수원목 A사이드테이블 3colors         28574
# 98482                          순수원목 A사이드테이블 3colors         28574
# 98483                          순수원목 A사이드테이블 3colors         28574
#
#        review_average  scrap_count  view_count  review_user_id review_status  \
# 0                4.64        30840      446469       1986643.0          확인완료
# 1                4.64        30840      446469       5804361.0          확인완료
# 2                4.64        30840      446469       4976972.0          확인완료
# 3                4.64        30840      446469       2692433.0          확인완료
# 4                4.64        30840      446469       2692433.0          확인완료
# ...               ...          ...         ...             ...           ...
# 98479            4.53        20610      162635       6122042.0          확인완료
# 98480            4.53        20610      162635       6201606.0          확인완료
# 98481            4.53        20610      162635       6723568.0          확인완료
# 98482            4.53        20610      162635       5816478.0          확인완료
# 98483            4.53        20610      162635       7101314.0          확인완료
#
#        ... review_star_durability  review_star_design  review_star_cost  \
# 0      ...                    2.0                 2.0               1.0
# 1      ...                    5.0                 5.0               5.0
# 2      ...                    5.0                 5.0               5.0
# 3      ...                    0.0                 0.0               0.0
# 4      ...                    0.0                 0.0               0.0
# ...    ...                    ...                 ...               ...
# 98479  ...                    5.0                 5.0               5.0
# 98480  ...                    5.0                 5.0               5.0
# 98481  ...                    2.0                 2.0               3.0
# 98482  ...                    1.0                 1.0               1.0
# 98483  ...                    5.0                 5.0               5.0
#
#        review_star_delivery  review_star_avg  product_info_id  \
# 0                       1.0              1.5         267218.0
# 1                       5.0              5.0         267218.0
# 2                       5.0              5.0         267218.0
# 3                       0.0              5.0         267218.0
# 4                       0.0              5.0         267218.0
# ...                     ...              ...              ...
# 98479                   5.0              5.0         388715.0
# 98480                   5.0              5.0         388715.0
# 98481                   5.0              3.0         388715.0
# 98482                   1.0              1.0         388715.0
# 98483                   5.0              5.0         388715.0
#
#                                production_info_name  \
# 0      [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)
# 1      [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)
# 2      [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)
# 3      [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)
# 4      [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)
# ...                                             ...
# 98479                          순수원목 A사이드테이블 3colors
# 98480                          순수원목 A사이드테이블 3colors
# 98481                          순수원목 A사이드테이블 3colors
# 98482                          순수원목 A사이드테이블 3colors
# 98483                          순수원목 A사이드테이블 3colors
#
#       production_info_brand_name                   production_info_explain  \
# 0                           듀커소파            사이즈 선택: 208cm / 색상 선택: 라이트 그레이
# 1                           듀커소파                사이즈 선택: 208cm / 색상 선택: 베이지
# 2                           듀커소파        사이즈 선택: DK053 (208cm) / 색상 선택: 베이지
# 3                           듀커소파  DK052(DK053) 3인용 풀커버 그레이 패브릭 소파 /발수 천 쇼파
# 4                           듀커소파  DK052(DK053) 3인용 풀커버 그레이 패브릭 소파 /발수 천 쇼파
# ...                          ...                                       ...
# 98479                     먼데이하우스                     상품명: A사이드테이블 / 색상: 우드
# 98480                     먼데이하우스                     상품명: A사이드테이블 / 색상: 우드
# 98481                     먼데이하우스                    상품명: A사이드테이블 / 색상: 화이트
# 98482                     먼데이하우스                     상품명: A사이드테이블 / 색상: 우드
# 98483                     먼데이하우스                    상품명: A사이드테이블 / 색상: 화이트
#
#       production_info_is_purchased
# 0                             True
# 1                             True
# 2                             True
# 3                            False
# 4                            False
# ...                            ...
# 98479                         True
# 98480                         True
# 98481                         True
# 98482                         True
# 98483                         True
#
# [98484 rows x 21 columns]

# %%
print(df.iloc[[0]])
# Out:
#    Unnamed: 0     id residence area region expertise color_list style_list  \
# 0           0  40578       아파트  30평    경기도     홈스타일링        NaN        NaN
#
#   constructions                              purchased_product_ids  \
# 0           NaN  [10865, 36591, 36592, 81695, 154085, 163351, 1...
#
#         family_list  like_count  reply_count  scrap_count  view_count  \
# 0  ['부모님과 함께 사는 집']          14            2          184        6311
#
#    share_count
# 0            0

# %%
purchased_product_ids_per_row =  df['purchased_product_ids'].values
purchased_product_ids_per_row
# Out:
# array(['[10865, 36591, 36592, 81695, 154085, 163351, 170233, 196822, 200864, 202802, 225435, 245841, 245842, 264792, 325601, 337047, 395253]',
#        '[61601, 68072, 97064, 108193, 153647, 194353, 206237, 244003, 250348, 259166, 289680, 324445, 363925, 408563, 414334, 435480, 477917, 490328, 492346, 563743, 609395, 609408, 609417, 609420, 609433, 609438, 609443, 609445, 609449, 609451]',
#        '[57577, 69119, 71718, 144799, 209658, 215597, 215770, 230216, 237059, 274302, 310706, 336837, 354736, 388715, 418107, 442226, 537368, 569826]',
#        ..., '[1, 4, 5, 6, 472, 484, 488, 494, 81927]',
#        '[8, 9, 10, 15, 16, 17, 18, 19, 20, 22, 49, 100, 371, 372, 373, 374, 435, 436, 11721, 13119, 15597, 16270, 30551, 33080, 33086, 46889, 387106]',
#        '[55, 1490, 2254, 2255, 2256, 2257, 2258, 2259, 2261, 2262, 2263]'],
#       dtype=object)

# %%
product_review_df = pd.read_csv('./input/data-product-review-v2.csv', sep='\t', encoding="UTF-16")
product_review_df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1      id  \
# 0           0           0.0  267218
# 1           1           1.0  267218
#
#                                            name  review_count  review_average  \
# 0  [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)          1930            4.64
# 1  [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)          1930            4.64
#
#    scrap_count  view_count  review_user_id review_status  ...  \
# 0        30840      446469       1986643.0          확인완료  ...
# 1        30840      446469       5804361.0          확인완료  ...
#
#   review_star_durability  review_star_design  review_star_cost  \
# 0                    2.0                 2.0               1.0
# 1                    5.0                 5.0               5.0
#
#    review_star_delivery  review_star_avg  product_info_id  \
# 0                   1.0              1.5         267218.0
# 1                   5.0              5.0         267218.0
#
#                            production_info_name production_info_brand_name  \
# 0  [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)                       듀커소파
# 1  [쿠폰할인] DK053 3인용 풀커버 그레이 발수 패브릭 소파 (스툴 기본포함)                       듀커소파
#
#           production_info_explain production_info_is_purchased
# 0  사이즈 선택: 208cm / 색상 선택: 라이트 그레이                         True
# 1      사이즈 선택: 208cm / 색상 선택: 베이지                         True
#
# [2 rows x 21 columns]
